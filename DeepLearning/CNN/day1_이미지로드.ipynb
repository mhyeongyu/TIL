# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

# %%
fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# ...
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
print(train_images.shape)
print(test_images.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
print(train_labels.shape)
print(test_labels.shape)
# Out:
# (60000,)
# (10000,)

# %%
plt.figure()
plt.imshow(train_images[6])
plt.show()

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
plt.figure()
plt.imshow(train_images[6])
plt.show()

# %%
plt.figure(figsize=(10,10))
for i in range(25):
  plt.subplot(5, 5, i+1)
  plt.xticks([])
  plt.yticks([])
  plt.imshow(train_images[i])
  plt.xlabel(class_names[train_labels[i]])
plt.show()

# %%
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import tensorflow_datasets as tfds

# %%
# tf.keras.utils.get_file(
#     fname, origin, untar=False, md5_hash=None, file_hash=None,
#     cache_subdir='datasets', hash_algorithm='auto',
#     extract=False, archive_format='auto', cache_dir=None
# )
#fname, 파일이름
#origin, 다운경로
#untar, 압축해제여부


import pathlib

dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file(origin=dataset_url,
                                   fname='flower_photos',
                                   untar=True)
data_dir = pathlib.Path(data_dir)
# Out:
# ...
# 228818944/228813984 [==============================] - 2s 0us/step

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 3670

# %%
roses = list(data_dir.glob('roses/*'))
PIL.Image.open(str(roses[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240 at 0x7FEAF610ACD0>

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
#tf.keras.preprocessing.image_dataset_from_directory, 해당 디렉토리에서 이미지 가져오기

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset='training',
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size
)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset='validation',
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size    
)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %%
#numpy(), array변환
#astype('uint8'), uint8(0~255사이 값으로 변환)
#train_ds.take(1), (1개씩 가져오기)

import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i+1)
    plt.imshow(images[i].numpy().astype('uint8'))
    plt.title(class_names[labels[i]])
    plt.axis('off')

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 180, 180, 3)
# (32,)

# %%
from tensorflow.keras import layers

normalization_layer = tf.keras.layers.experimental.preprocessing.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]

# %%
#batch_size, input data_size(데이터 수)

first_image.shape
# Out:
# TensorShape([180, 180, 3])

# %%
#AUTOTUNE, buffer_size 동적으로 변경
#buffer_size, =batch_size? 
AUTOTUNE = tf.data.experimental.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
var_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
