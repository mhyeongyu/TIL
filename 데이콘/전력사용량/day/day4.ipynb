# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

from lightgbm import LGBMRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor


from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
# train = pd.read_csv('edit_train.csv')
# test = pd.read_csv('edit_test.csv')
# submission = pd.read_csv('energy/sample_submission.csv', encoding='cp949')

# %%
def data_load(columns):
    train = pd.read_csv('edit_train.csv')
    test = pd.read_csv('edit_test.csv')
    submission = pd.read_csv('energy/sample_submission.csv', encoding='cp949')
    
    train = train.drop(columns, axis=1)
    test = test.drop(columns, axis=1)

    features = train.drop('전력사용량(kWh)', axis=1)
    labels = train[['전력사용량(kWh)']]
    
    return train, test, submission, features, labels

# %% [markdown]
# ## KFold

# %%
def Kfold(train, N=None):
    kfold = KFold(n_splits=N, shuffle=True, random_state=0)
    fold = 1
    models = {}

    for train_idx, valid_idx in kfold.split(train):
        print('\n ================== Fold {} =================='.format(fold))

        X_train, X_valid = features.iloc[train_idx, :], features.iloc[valid_idx, :]
        y_train, y_valid = labels.iloc[train_idx, :], labels.iloc[valid_idx, :]

        model = LGBMRegressor(n_estimators=10000, random_state=0)
        model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_valid, y_valid)], eval_metric= 'rmse', early_stopping_rounds=100, verbose=500)
        models[fold] = model
        
        pred = model.predict(X_valid)
        
        mae = mean_absolute_error(y_valid, pred)
        mse = mean_squared_error(y_valid, pred)
        rmse = np.sqrt(mean_squared_error(y_valid, pred))
        
        print('='*30)
        print('MAE: {0:.4f} \nMSE: {1:.4f} \nRMSE: {2:.4f}'.format(mae, mse, rmse))
        print('='*30)
        
        fold += 1
    
    return models

# %%
columns = ['date_time']

train, test, submission, features, labels = data_load(columns)
models = Kfold(train, 5)
# Out:
#  ================== Fold 1 ==================
# Training until validation scores don't improve for 100 rounds
# [500]	training's rmse: 172.825	training's l2: 29868.4	valid_1's rmse: 218.461	valid_1's l2: 47725.3
# [1000]	training's rmse: 141.719	training's l2: 20084.3	valid_1's rmse: 203.324	valid_1's l2: 41340.6
# [1500]	training's rmse: 124.142	training's l2: 15411.1	valid_1's rmse: 197.813	valid_1's l2: 39130
# [2000]	training's rmse: 111.882	training's l2: 12517.7	valid_1's rmse: 194.25	valid_1's l2: 37733.2
# [2500]	training's rmse: 102.173	training's l2: 10439.2	valid_1's rmse: 192.228	valid_1's l2: 36951.7
# [3000]	training's rmse: 94.2455	training's l2: 8882.22	valid_1's rmse: 190.697	valid_1's l2: 36365.3
# [3500]	training's rmse: 87.3962	training's l2: 7638.1	valid_1's rmse: 189.433	valid_1's l2: 35884.7
# [4000]	training's rmse: 81.6608	training's l2: 6668.49	valid_1's rmse: 188.591	valid_1's l2: 35566.6
# [4500]	training's rmse: 76.7445	training's l2: 5889.72	valid_1's rmse: 187.865	valid_1's l2: 35293.1
# [5000]	training's rmse: 72.335	training's l2: 5232.35	valid_1's rmse: 187.425	valid_1's l2: 35128.1
# [5500]	training's rmse: 68.1838	training's l2: 4649.03	valid_1's rmse: 187.125	valid_1's l2: 35015.8
# [6000]	training's rmse: 64.4543	training's l2: 4154.36	valid_1's rmse: 186.586	valid_1's l2: 34814.4
# [6500]	training's rmse: 61.1521	training's l2: 3739.58	valid_1's rmse: 186.216	valid_1's l2: 34676.5
# Early stopping, best iteration is:
# [6492]	training's rmse: 61.1871	training's l2: 3743.86	valid_1's rmse: 186.21	valid_1's l2: 34674
# ==============================
# MAE: 96.9149
# MSE: 34673.9969
# RMSE: 186.2096
# ==============================
#
#  ================== Fold 2 ==================
# Training until validation scores don't improve for 100 rounds
# [500]	training's rmse: 171.931	training's l2: 29560.4	valid_1's rmse: 224.957	valid_1's l2: 50605.9
# [1000]	training's rmse: 142.196	training's l2: 20219.8	valid_1's rmse: 212.25	valid_1's l2: 45050
# [1500]	training's rmse: 124.987	training's l2: 15621.6	valid_1's rmse: 207.212	valid_1's l2: 42937
# [2000]	training's rmse: 112.438	training's l2: 12642.2	valid_1's rmse: 203.821	valid_1's l2: 41543.1
# [2500]	training's rmse: 102.869	training's l2: 10582	valid_1's rmse: 201.516	valid_1's l2: 40608.6
# [3000]	training's rmse: 94.5618	training's l2: 8941.93	valid_1's rmse: 199.791	valid_1's l2: 39916.4
# [3500]	training's rmse: 87.4235	training's l2: 7642.86	valid_1's rmse: 198.566	valid_1's l2: 39428.5
# [4000]	training's rmse: 81.6454	training's l2: 6665.97	valid_1's rmse: 197.839	valid_1's l2: 39140.2
# [4500]	training's rmse: 76.3712	training's l2: 5832.56	valid_1's rmse: 196.994	valid_1's l2: 38806.7
# [5000]	training's rmse: 71.6858	training's l2: 5138.85	valid_1's rmse: 196.346	valid_1's l2: 38551.9
# [5500]	training's rmse: 67.6569	training's l2: 4577.46	valid_1's rmse: 195.931	valid_1's l2: 38388.9
# [6000]	training's rmse: 64.0523	training's l2: 4102.7	valid_1's rmse: 195.596	valid_1's l2: 38257.8
# Early stopping, best iteration is:
# [6033]	training's rmse: 63.8364	training's l2: 4075.08	valid_1's rmse: 195.562	valid_1's l2: 38244.6
# ==============================
# MAE: 96.9258
# MSE: 38244.5789
# RMSE: 195.5622
# ==============================
#
#  ================== Fold 3 ==================
# Training until validation scores don't improve for 100 rounds
# [500]	training's rmse: 173.147	training's l2: 29979.7	valid_1's rmse: 218.098	valid_1's l2: 47567
# [1000]	training's rmse: 142.981	training's l2: 20443.5	valid_1's rmse: 204.078	valid_1's l2: 41648
# [1500]	training's rmse: 125.03	training's l2: 15632.6	valid_1's rmse: 197.415	valid_1's l2: 38972.7
# [2000]	training's rmse: 112.231	training's l2: 12595.7	valid_1's rmse: 194.298	valid_1's l2: 37751.6
# [2500]	training's rmse: 102.155	training's l2: 10435.7	valid_1's rmse: 191.928	valid_1's l2: 36836.4
# [3000]	training's rmse: 94.3552	training's l2: 8902.9	valid_1's rmse: 190.483	valid_1's l2: 36283.7
# [3500]	training's rmse: 87.8596	training's l2: 7719.31	valid_1's rmse: 189.587	valid_1's l2: 35943.1
# [4000]	training's rmse: 82.0145	training's l2: 6726.38	valid_1's rmse: 188.875	valid_1's l2: 35673.8
# [4500]	training's rmse: 77.0426	training's l2: 5935.57	valid_1's rmse: 188.414	valid_1's l2: 35499.7
# [5000]	training's rmse: 72.5803	training's l2: 5267.9	valid_1's rmse: 187.917	valid_1's l2: 35312.9
# [5500]	training's rmse: 68.4454	training's l2: 4684.77	valid_1's rmse: 187.535	valid_1's l2: 35169.2
# [6000]	training's rmse: 64.7807	training's l2: 4196.54	valid_1's rmse: 187.211	valid_1's l2: 35047.9
# [6500]	training's rmse: 61.3865	training's l2: 3768.3	valid_1's rmse: 186.957	valid_1's l2: 34952.9
# Early stopping, best iteration is:
# [6816]	training's rmse: 59.2779	training's l2: 3513.87	valid_1's rmse: 186.812	valid_1's l2: 34898.6
# ==============================
# MAE: 98.2353
# MSE: 34898.5585
# RMSE: 186.8116
# ==============================
#
#  ================== Fold 4 ==================
# Training until validation scores don't improve for 100 rounds
# [500]	training's rmse: 173.033	training's l2: 29940.4	valid_1's rmse: 214.788	valid_1's l2: 46134
# [1000]	training's rmse: 141.949	training's l2: 20149.6	valid_1's rmse: 200.846	valid_1's l2: 40339.2
# [1500]	training's rmse: 123.912	training's l2: 15354.3	valid_1's rmse: 194.349	valid_1's l2: 37771.3
# [2000]	training's rmse: 112.118	training's l2: 12570.5	valid_1's rmse: 191.092	valid_1's l2: 36516.1
# [2500]	training's rmse: 101.924	training's l2: 10388.5	valid_1's rmse: 188.31	valid_1's l2: 35460.6
# [3000]	training's rmse: 94.4104	training's l2: 8913.32	valid_1's rmse: 187.001	valid_1's l2: 34969.5
# [3500]	training's rmse: 87.9118	training's l2: 7728.48	valid_1's rmse: 186.064	valid_1's l2: 34620
# [4000]	training's rmse: 82.3552	training's l2: 6782.39	valid_1's rmse: 185.357	valid_1's l2: 34357.2
# [4500]	training's rmse: 77.1977	training's l2: 5959.49	valid_1's rmse: 184.806	valid_1's l2: 34153.2
# [5000]	training's rmse: 72.6552	training's l2: 5278.78	valid_1's rmse: 184.347	valid_1's l2: 33983.9
# [5500]	training's rmse: 68.6295	training's l2: 4710.01	valid_1's rmse: 183.949	valid_1's l2: 33837.3
# [6000]	training's rmse: 65.1399	training's l2: 4243.21	valid_1's rmse: 183.555	valid_1's l2: 33692.6
# [6500]	training's rmse: 61.9052	training's l2: 3832.25	valid_1's rmse: 183.283	valid_1's l2: 33592.7
# [7000]	training's rmse: 58.7433	training's l2: 3450.78	valid_1's rmse: 182.933	valid_1's l2: 33464.7
# [7500]	training's rmse: 56.0884	training's l2: 3145.91	valid_1's rmse: 182.751	valid_1's l2: 33398.1
# [8000]	training's rmse: 53.5366	training's l2: 2866.17	valid_1's rmse: 182.58	valid_1's l2: 33335.3
# Early stopping, best iteration is:
# [7986]	training's rmse: 53.6109	training's l2: 2874.13	valid_1's rmse: 182.558	valid_1's l2: 33327.6
# ==============================
# MAE: 96.0274
# MSE: 33327.5940
# RMSE: 182.5585
# ==============================
#
#  ================== Fold 5 ==================
# Training until validation scores don't improve for 100 rounds
# [500]	training's rmse: 173.58	training's l2: 30130.1	valid_1's rmse: 208.542	valid_1's l2: 43489.6
# [1000]	training's rmse: 141.644	training's l2: 20063.1	valid_1's rmse: 194.428	valid_1's l2: 37802.3
# [1500]	training's rmse: 123.866	training's l2: 15342.9	valid_1's rmse: 189.334	valid_1's l2: 35847.4
# [2000]	training's rmse: 111.157	training's l2: 12355.9	valid_1's rmse: 186.057	valid_1's l2: 34617
# [2500]	training's rmse: 101.585	training's l2: 10319.5	valid_1's rmse: 183.939	valid_1's l2: 33833.6
# [3000]	training's rmse: 93.3195	training's l2: 8708.52	valid_1's rmse: 182.29	valid_1's l2: 33229.5
# [3500]	training's rmse: 86.4586	training's l2: 7475.09	valid_1's rmse: 181.118	valid_1's l2: 32803.7
# [4000]	training's rmse: 80.6141	training's l2: 6498.63	valid_1's rmse: 180.353	valid_1's l2: 32527.3
# [4500]	training's rmse: 75.4462	training's l2: 5692.13	valid_1's rmse: 179.821	valid_1's l2: 32335.6
# [5000]	training's rmse: 71.2815	training's l2: 5081.05	valid_1's rmse: 179.243	valid_1's l2: 32128
# Early stopping, best iteration is:
# [5338]	training's rmse: 68.5541	training's l2: 4699.67	valid_1's rmse: 179.04	valid_1's l2: 32055.4
# ==============================
# MAE: 97.6517
# MSE: 32055.4495
# RMSE: 179.0404
# ==============================

# %% [markdown]
# ## StratifiedKFold

# %%
def sKfold(train, N=None):
    skfold = StratifiedKFold(n_splits=N, shuffle=True, random_state=0)
    fold = 1
    models = {}

    for train_idx, valid_idx in skfold.split(features, features['num']):
        print('\n ================== sKFold {} =================='.format(fold))

        X_train, X_valid = features.iloc[train_idx, :], features.iloc[valid_idx, :]
        y_train, y_valid = labels.iloc[train_idx, :], labels.iloc[valid_idx, :]

        model = LGBMRegressor(n_estimators=10000, random_state=0)
        model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_valid, y_valid)], eval_metric= 'rmse', early_stopping_rounds=30, verbose=500)
        models[fold] = model
        
        pred = model.predict(X_valid)
        
        mae = mean_absolute_error(y_valid, pred)
        mse = mean_squared_error(y_valid, pred)
        rmse = np.sqrt(mean_squared_error(y_valid, pred))
        
        print('='*30)
        print('MAE: {0:.4f} \nMSE: {1:.4f} \nRMSE: {2:.4f}'.format(mae, mse, rmse))
        print('='*30)
        
        fold += 1
    
    return models

# %%
train, test, submission, features, labels = data_load(columns)
models = sKfold(train, 5)
# Out:
#  ================== sKFold 1 ==================
# Training until validation scores don't improve for 30 rounds
# [500]	training's rmse: 173.69	training's l2: 30168.3	valid_1's rmse: 210.902	valid_1's l2: 44479.5
# [1000]	training's rmse: 143.653	training's l2: 20636.1	valid_1's rmse: 197.576	valid_1's l2: 39036.4
# [1500]	training's rmse: 125.376	training's l2: 15719.1	valid_1's rmse: 191.488	valid_1's l2: 36667.5
# [2000]	training's rmse: 112.224	training's l2: 12594.3	valid_1's rmse: 187.661	valid_1's l2: 35216.8
# [2500]	training's rmse: 102.496	training's l2: 10505.5	valid_1's rmse: 185.366	valid_1's l2: 34360.6
# Early stopping, best iteration is:
# [2829]	training's rmse: 97.1903	training's l2: 9445.96	valid_1's rmse: 184.55	valid_1's l2: 34058.7
# ==============================
# MAE: 99.9892
# MSE: 34058.7068
# RMSE: 184.5500
# ==============================
#
#  ================== sKFold 2 ==================
# Training until validation scores don't improve for 30 rounds
# [500]	training's rmse: 171.586	training's l2: 29441.9	valid_1's rmse: 219.79	valid_1's l2: 48307.6
# [1000]	training's rmse: 141.764	training's l2: 20096.9	valid_1's rmse: 206.108	valid_1's l2: 42480.3
# [1500]	training's rmse: 124.253	training's l2: 15438.8	valid_1's rmse: 200.155	valid_1's l2: 40061.9
# [2000]	training's rmse: 111.713	training's l2: 12479.9	valid_1's rmse: 196.191	valid_1's l2: 38490.9
# [2500]	training's rmse: 102.057	training's l2: 10415.6	valid_1's rmse: 193.956	valid_1's l2: 37618.7
# [3000]	training's rmse: 94.4494	training's l2: 8920.7	valid_1's rmse: 192.256	valid_1's l2: 36962.5
# [3500]	training's rmse: 87.5745	training's l2: 7669.3	valid_1's rmse: 190.946	valid_1's l2: 36460.4
# [4000]	training's rmse: 81.5561	training's l2: 6651.4	valid_1's rmse: 189.992	valid_1's l2: 36096.8
# Early stopping, best iteration is:
# [4037]	training's rmse: 81.1609	training's l2: 6587.09	valid_1's rmse: 189.928	valid_1's l2: 36072.5
# ==============================
# MAE: 97.8186
# MSE: 36072.4824
# RMSE: 189.9276
# ==============================
#
#  ================== sKFold 3 ==================
# Training until validation scores don't improve for 30 rounds
# [500]	training's rmse: 173.127	training's l2: 29973	valid_1's rmse: 232.559	valid_1's l2: 54083.9
# [1000]	training's rmse: 141.868	training's l2: 20126.6	valid_1's rmse: 217.073	valid_1's l2: 47120.6
# [1500]	training's rmse: 123.859	training's l2: 15341.1	valid_1's rmse: 211.245	valid_1's l2: 44624.6
# [2000]	training's rmse: 111.5	training's l2: 12432.2	valid_1's rmse: 207.961	valid_1's l2: 43247.8
# [2500]	training's rmse: 101.56	training's l2: 10314.5	valid_1's rmse: 205.353	valid_1's l2: 42170
# [3000]	training's rmse: 93.8427	training's l2: 8806.46	valid_1's rmse: 203.685	valid_1's l2: 41487.7
# [3500]	training's rmse: 87.1507	training's l2: 7595.24	valid_1's rmse: 202.357	valid_1's l2: 40948.5
# Early stopping, best iteration is:
# [3578]	training's rmse: 86.2017	training's l2: 7430.73	valid_1's rmse: 202.145	valid_1's l2: 40862.6
# ==============================
# MAE: 101.3054
# MSE: 40862.5715
# RMSE: 202.1449
# ==============================
#
#  ================== sKFold 4 ==================
# Training until validation scores don't improve for 30 rounds
# [500]	training's rmse: 172.571	training's l2: 29780.8	valid_1's rmse: 214.878	valid_1's l2: 46172.4
# [1000]	training's rmse: 142.419	training's l2: 20283.1	valid_1's rmse: 202.526	valid_1's l2: 41016.9
# [1500]	training's rmse: 125.352	training's l2: 15713.1	valid_1's rmse: 196.854	valid_1's l2: 38751.7
# [2000]	training's rmse: 112.164	training's l2: 12580.9	valid_1's rmse: 193.23	valid_1's l2: 37337.8
# [2500]	training's rmse: 102.269	training's l2: 10458.9	valid_1's rmse: 191.148	valid_1's l2: 36537.4
# [3000]	training's rmse: 94.5183	training's l2: 8933.7	valid_1's rmse: 189.527	valid_1's l2: 35920.7
# [3500]	training's rmse: 87.8035	training's l2: 7709.46	valid_1's rmse: 188.696	valid_1's l2: 35606.3
# Early stopping, best iteration is:
# [3470]	training's rmse: 88.2515	training's l2: 7788.33	valid_1's rmse: 188.663	valid_1's l2: 35593.6
# ==============================
# MAE: 99.1712
# MSE: 35593.5594
# RMSE: 188.6626
# ==============================
#
#  ================== sKFold 5 ==================
# Training until validation scores don't improve for 30 rounds
# [500]	training's rmse: 173.298	training's l2: 30032.1	valid_1's rmse: 206.664	valid_1's l2: 42710
# [1000]	training's rmse: 142.087	training's l2: 20188.7	valid_1's rmse: 193.069	valid_1's l2: 37275.5
# [1500]	training's rmse: 124.361	training's l2: 15465.7	valid_1's rmse: 187.545	valid_1's l2: 35173.2
# [2000]	training's rmse: 111.826	training's l2: 12505.1	valid_1's rmse: 184.525	valid_1's l2: 34049.4
# [2500]	training's rmse: 102.576	training's l2: 10521.7	valid_1's rmse: 182.06	valid_1's l2: 33146
# [3000]	training's rmse: 94.7917	training's l2: 8985.47	valid_1's rmse: 180.412	valid_1's l2: 32548.4
# [3500]	training's rmse: 88.3106	training's l2: 7798.76	valid_1's rmse: 179.476	valid_1's l2: 32211.8
# [4000]	training's rmse: 82.3658	training's l2: 6784.12	valid_1's rmse: 178.506	valid_1's l2: 31864.4
# Early stopping, best iteration is:
# [4060]	training's rmse: 81.685	training's l2: 6672.43	valid_1's rmse: 178.4	valid_1's l2: 31826.4
# ==============================
# MAE: 97.6225
# MSE: 31826.4218
# RMSE: 178.3996
# ==============================

# %% [markdown]
# ## RandomForest

# %%
def KfoldForest(train, N=None):
    kfold = KFold(n_splits=N, shuffle=True, random_state=0)
    fold = 1
    models = {}

    for train_idx, valid_idx in kfold.split(train):
        print('\n ================== Fold {} =================='.format(fold))

        X_train, X_valid = features.iloc[train_idx, :], features.iloc[valid_idx, :]
        y_train, y_valid = labels.iloc[train_idx, :], labels.iloc[valid_idx, :]
        
        
        model = RandomForestRegressor(random_state=0)
        model.fit(X_train, y_train)
        pred = model.predict(X_valid)
        
        mae = mean_absolute_error(y_valid, pred)
        mse = mean_squared_error(y_valid, pred)
        rmse = np.sqrt(mean_squared_error(y_valid, pred))
        
        print('MAE: {0:.4f} \nMSE: {1:.4f} \nRMSE: {2:.4f}'.format(mae, mse, rmse))
        
        models[fold] = model

        fold += 1
    
    return models

# %%
train, test, submission, features, labels = data_load(columns)
models = KfoldForest(train, 5)
# Out:
#  ================== Fold 1 ==================
# MAE: 121.1460
# MSE: 70082.4526
# RMSE: 264.7309
#
#  ================== Fold 2 ==================
# MAE: 118.6476
# MSE: 63287.0983
# RMSE: 251.5693
#
#  ================== Fold 3 ==================
# MAE: 119.4404
# MSE: 54014.8691
# RMSE: 232.4110
#
#  ================== Fold 4 ==================
# MAE: 117.9968
# MSE: 56927.5535
# RMSE: 238.5950
#
#  ================== Fold 5 ==================
# MAE: 118.4614
# MSE: 57056.5039
# RMSE: 238.8650

# %%
submission = pd.read_csv('energy/sample_submission.csv', encoding='cp949')

for i in range(1, 6):
    submission['answer'] += models[i].predict(test)/5

submission.to_csv('lgbm_day3_1.csv', index=False)

# %%
submission = pd.read_csv('energy/sample_submission.csv', encoding='cp949')

for i in range(1, 6):
    submission['answer'] += models[i].predict(test)/5

submission.to_csv('lgbm_day3_2.csv', index=False)
