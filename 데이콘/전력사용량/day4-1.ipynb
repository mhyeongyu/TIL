# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

from lightgbm import LGBMRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor


from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
# train = pd.read_csv('edit_train.csv')
# test = pd.read_csv('edit_test.csv')
# submission = pd.read_csv('energy/sample_submission.csv', encoding='cp949')

# %%
def data_load(columns):
    train = pd.read_csv('edit_train.csv')
    test = pd.read_csv('edit_test.csv')
    submission = pd.read_csv('energy/sample_submission.csv', encoding='cp949')
    
    train = train.drop(columns, axis=1)
    test = test.drop(columns, axis=1)

    features = train.drop('전력사용량(kWh)', axis=1)
    labels = train[['전력사용량(kWh)']]
    
    return train, test, submission, features, labels

# %% [markdown]
# ## KFold

# %%
def Kfold(train, N=None):
    kfold = KFold(n_splits=N, shuffle=True, random_state=0)
    fold = 1
    models = {}

    for train_idx, valid_idx in kfold.split(train):
        print('\n ================== Fold {} =================='.format(fold))

        X_train, X_valid = features.iloc[train_idx, :], features.iloc[valid_idx, :]
        y_train, y_valid = labels.iloc[train_idx, :], labels.iloc[valid_idx, :]

        model = LGBMRegressor(n_estimators=10000, random_state=0)
        model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_valid, y_valid)], eval_metric= 'rmse', early_stopping_rounds=100, verbose=500)
        models[fold] = model
        
        pred = model.predict(X_valid)
        
        mae = mean_absolute_error(y_valid, pred)
        mse = mean_squared_error(y_valid, pred)
        rmse = np.sqrt(mean_squared_error(y_valid, pred))
        
        print('='*30)
        print('MAE: {0:.4f} \nMSE: {1:.4f} \nRMSE: {2:.4f}'.format(mae, mse, rmse))
        print('='*30)
        
        fold += 1
    
    return models

# %%
train.columns
# Out:
# Index(['전력사용량(kWh)', '강수량(mm)', '일조(hr)', '비전기냉방설비운영', '태양광보유', 'hour',
#        'weekday', 'holiday', 'perceived_temperature', 'discomfort_index',
#        'ref_day', 'hour_assignment', 'gmm_num_assignment'],
#       dtype='object')

# %%
columns = ['date_time', 'hour_assignment', 'gmm_num_assignment']

train, test, submission, features, labels = data_load(columns)
models = Kfold(train, 5)
# Out:
#  ================== Fold 1 ==================
# Training until validation scores don't improve for 100 rounds
# [500]	training's rmse: 179.77	training's l2: 32317.2	valid_1's rmse: 230.582	valid_1's l2: 53168
# [1000]	training's rmse: 147.807	training's l2: 21847	valid_1's rmse: 214.227	valid_1's l2: 45893.4
# [1500]	training's rmse: 129.112	training's l2: 16670	valid_1's rmse: 207.368	valid_1's l2: 43001.5
# [2000]	training's rmse: 116.128	training's l2: 13485.8	valid_1's rmse: 203.269	valid_1's l2: 41318.3
# [2500]	training's rmse: 106.013	training's l2: 11238.7	valid_1's rmse: 200.64	valid_1's l2: 40256.3
# [3000]	training's rmse: 97.5821	training's l2: 9522.26	valid_1's rmse: 198.939	valid_1's l2: 39576.8
# [3500]	training's rmse: 91.109	training's l2: 8300.85	valid_1's rmse: 197.746	valid_1's l2: 39103.6
# [4000]	training's rmse: 84.859	training's l2: 7201.06	valid_1's rmse: 196.557	valid_1's l2: 38634.6
# [4500]	training's rmse: 79.3607	training's l2: 6298.12	valid_1's rmse: 195.864	valid_1's l2: 38362.8
# [5000]	training's rmse: 74.7118	training's l2: 5581.86	valid_1's rmse: 195.227	valid_1's l2: 38113.6
# [5500]	training's rmse: 70.4147	training's l2: 4958.23	valid_1's rmse: 194.817	valid_1's l2: 37953.7
# [6000]	training's rmse: 66.655	training's l2: 4442.89	valid_1's rmse: 194.342	valid_1's l2: 37768.8
# [6500]	training's rmse: 63.2434	training's l2: 3999.72	valid_1's rmse: 193.905	valid_1's l2: 37599.2
# [7000]	training's rmse: 60.1977	training's l2: 3623.76	valid_1's rmse: 193.551	valid_1's l2: 37461.9
# [7500]	training's rmse: 57.2346	training's l2: 3275.79	valid_1's rmse: 193.234	valid_1's l2: 37339.6
# Early stopping, best iteration is:
# [7642]	training's rmse: 56.3425	training's l2: 3174.48	valid_1's rmse: 193.135	valid_1's l2: 37301.3
# ==============================
# MAE: 99.6324
# MSE: 37301.2823
# RMSE: 193.1354
# ==============================
#
#  ================== Fold 2 ==================
# Training until validation scores don't improve for 100 rounds
# [500]	training's rmse: 178.733	training's l2: 31945.6	valid_1's rmse: 233.246	valid_1's l2: 54403.6
# [1000]	training's rmse: 147.495	training's l2: 21754.9	valid_1's rmse: 219.073	valid_1's l2: 47993.1
# [1500]	training's rmse: 128.939	training's l2: 16625.2	valid_1's rmse: 212.193	valid_1's l2: 45025.8
# [2000]	training's rmse: 116.44	training's l2: 13558.4	valid_1's rmse: 208.757	valid_1's l2: 43579.6
# [2500]	training's rmse: 105.894	training's l2: 11213.4	valid_1's rmse: 205.852	valid_1's l2: 42375.1
# [3000]	training's rmse: 97.7994	training's l2: 9564.72	valid_1's rmse: 203.94	valid_1's l2: 41591.4
# [3500]	training's rmse: 91.3419	training's l2: 8343.34	valid_1's rmse: 202.912	valid_1's l2: 41173.3
# [4000]	training's rmse: 85.2563	training's l2: 7268.64	valid_1's rmse: 201.849	valid_1's l2: 40743.1
# [4500]	training's rmse: 79.9755	training's l2: 6396.09	valid_1's rmse: 201.212	valid_1's l2: 40486.3
# [5000]	training's rmse: 75.159	training's l2: 5648.87	valid_1's rmse: 200.406	valid_1's l2: 40162.6
# [5500]	training's rmse: 70.9735	training's l2: 5037.23	valid_1's rmse: 200.118	valid_1's l2: 40047
# [6000]	training's rmse: 67.2553	training's l2: 4523.27	valid_1's rmse: 199.702	valid_1's l2: 39881
# Early stopping, best iteration is:
# [6392]	training's rmse: 64.633	training's l2: 4177.43	valid_1's rmse: 199.478	valid_1's l2: 39791.7
# ==============================
# MAE: 99.0752
# MSE: 39791.6569
# RMSE: 199.4785
# ==============================
#
#  ================== Fold 3 ==================
# Training until validation scores don't improve for 100 rounds
# [500]	training's rmse: 180.152	training's l2: 32454.7	valid_1's rmse: 225.428	valid_1's l2: 50817.7
# [1000]	training's rmse: 147.236	training's l2: 21678.3	valid_1's rmse: 208.903	valid_1's l2: 43640.3
# [1500]	training's rmse: 128.408	training's l2: 16488.5	valid_1's rmse: 202.666	valid_1's l2: 41073.5
# [2000]	training's rmse: 115.781	training's l2: 13405.2	valid_1's rmse: 199.533	valid_1's l2: 39813.3
# [2500]	training's rmse: 105.391	training's l2: 11107.2	valid_1's rmse: 197.14	valid_1's l2: 38864.2
# [3000]	training's rmse: 96.8609	training's l2: 9382.04	valid_1's rmse: 195.531	valid_1's l2: 38232.3
# [3500]	training's rmse: 89.9051	training's l2: 8082.92	valid_1's rmse: 194.732	valid_1's l2: 37920.4
# [4000]	training's rmse: 84.0138	training's l2: 7058.31	valid_1's rmse: 193.964	valid_1's l2: 37621.8
# [4500]	training's rmse: 78.8946	training's l2: 6224.35	valid_1's rmse: 193.293	valid_1's l2: 37362.3
# [5000]	training's rmse: 74.1729	training's l2: 5501.61	valid_1's rmse: 192.757	valid_1's l2: 37155.2
# [5500]	training's rmse: 70.0397	training's l2: 4905.56	valid_1's rmse: 192.483	valid_1's l2: 37049.6
# [6000]	training's rmse: 66.4522	training's l2: 4415.89	valid_1's rmse: 192.211	valid_1's l2: 36945.1
# [6500]	training's rmse: 63.1184	training's l2: 3983.94	valid_1's rmse: 192.022	valid_1's l2: 36872.6
# [7000]	training's rmse: 60.1501	training's l2: 3618.04	valid_1's rmse: 191.794	valid_1's l2: 36784.8
# Early stopping, best iteration is:
# [7230]	training's rmse: 58.7594	training's l2: 3452.67	valid_1's rmse: 191.688	valid_1's l2: 36744.4
# ==============================
# MAE: 100.0910
# MSE: 36744.4379
# RMSE: 191.6884
# ==============================
#
#  ================== Fold 4 ==================
# Training until validation scores don't improve for 100 rounds
# [500]	training's rmse: 180.27	training's l2: 32497.2	valid_1's rmse: 225.42	valid_1's l2: 50814
# [1000]	training's rmse: 147.851	training's l2: 21859.9	valid_1's rmse: 209.906	valid_1's l2: 44060.5
# [1500]	training's rmse: 129.647	training's l2: 16808.4	valid_1's rmse: 203.226	valid_1's l2: 41300.8
# [2000]	training's rmse: 116.437	training's l2: 13557.7	valid_1's rmse: 199.037	valid_1's l2: 39615.6
# [2500]	training's rmse: 106.02	training's l2: 11240.3	valid_1's rmse: 196.062	valid_1's l2: 38440.5
# [3000]	training's rmse: 97.8335	training's l2: 9571.4	valid_1's rmse: 194.27	valid_1's l2: 37740.8
# [3500]	training's rmse: 90.8748	training's l2: 8258.23	valid_1's rmse: 192.841	valid_1's l2: 37187.6
# [4000]	training's rmse: 84.9134	training's l2: 7210.28	valid_1's rmse: 191.829	valid_1's l2: 36798.5
# [4500]	training's rmse: 79.6325	training's l2: 6341.34	valid_1's rmse: 191.088	valid_1's l2: 36514.5
# [5000]	training's rmse: 74.9612	training's l2: 5619.18	valid_1's rmse: 190.568	valid_1's l2: 36316.1
# [5500]	training's rmse: 70.832	training's l2: 5017.17	valid_1's rmse: 190.062	valid_1's l2: 36123.7
# [6000]	training's rmse: 67.0272	training's l2: 4492.64	valid_1's rmse: 189.65	valid_1's l2: 35967.3
# [6500]	training's rmse: 63.5645	training's l2: 4040.45	valid_1's rmse: 189.341	valid_1's l2: 35850.2
# [7000]	training's rmse: 60.4678	training's l2: 3656.35	valid_1's rmse: 188.99	valid_1's l2: 35717
# [7500]	training's rmse: 57.643	training's l2: 3322.72	valid_1's rmse: 188.756	valid_1's l2: 35628.9
# [8000]	training's rmse: 54.9526	training's l2: 3019.79	valid_1's rmse: 188.534	valid_1's l2: 35545
# [8500]	training's rmse: 52.4783	training's l2: 2753.97	valid_1's rmse: 188.367	valid_1's l2: 35481.9
# [9000]	training's rmse: 50.0219	training's l2: 2502.19	valid_1's rmse: 188.226	valid_1's l2: 35429
# Early stopping, best iteration is:
# [9230]	training's rmse: 48.9551	training's l2: 2396.6	valid_1's rmse: 188.131	valid_1's l2: 35393.1
# ==============================
# MAE: 98.4092
# MSE: 35393.1195
# RMSE: 188.1306
# ==============================
#
#  ================== Fold 5 ==================
# Training until validation scores don't improve for 100 rounds
# [500]	training's rmse: 179.169	training's l2: 32101.6	valid_1's rmse: 215.88	valid_1's l2: 46604.1
# [1000]	training's rmse: 147.302	training's l2: 21697.8	valid_1's rmse: 201.684	valid_1's l2: 40676.4
# [1500]	training's rmse: 128.991	training's l2: 16638.6	valid_1's rmse: 195.666	valid_1's l2: 38285.4
# [2000]	training's rmse: 115.999	training's l2: 13455.8	valid_1's rmse: 192.097	valid_1's l2: 36901.3
# [2500]	training's rmse: 105.4	training's l2: 11109.2	valid_1's rmse: 189.573	valid_1's l2: 35937.9
# [3000]	training's rmse: 96.842	training's l2: 9378.37	valid_1's rmse: 187.647	valid_1's l2: 35211.5
# [3500]	training's rmse: 89.7649	training's l2: 8057.74	valid_1's rmse: 186.429	valid_1's l2: 34755.9
# [4000]	training's rmse: 83.9888	training's l2: 7054.12	valid_1's rmse: 185.656	valid_1's l2: 34468
# [4500]	training's rmse: 78.5816	training's l2: 6175.07	valid_1's rmse: 184.778	valid_1's l2: 34142.9
# [5000]	training's rmse: 74.0704	training's l2: 5486.43	valid_1's rmse: 184.316	valid_1's l2: 33972.4
# [5500]	training's rmse: 69.9053	training's l2: 4886.75	valid_1's rmse: 183.85	valid_1's l2: 33800.8
# [6000]	training's rmse: 66.0194	training's l2: 4358.56	valid_1's rmse: 183.537	valid_1's l2: 33685.7
# [6500]	training's rmse: 62.7061	training's l2: 3932.05	valid_1's rmse: 183.191	valid_1's l2: 33558.9
# [7000]	training's rmse: 59.6715	training's l2: 3560.69	valid_1's rmse: 182.942	valid_1's l2: 33467.9
# [7500]	training's rmse: 56.7854	training's l2: 3224.59	valid_1's rmse: 182.654	valid_1's l2: 33362.6
# Early stopping, best iteration is:
# [7817]	training's rmse: 55.0134	training's l2: 3026.47	valid_1's rmse: 182.51	valid_1's l2: 33310
# ==============================
# MAE: 99.0864
# MSE: 33309.9913
# RMSE: 182.5102
# ==============================

# %% [markdown]
# ## StratifiedKFold

# %%
def sKfold(train, N=None):
    skfold = StratifiedKFold(n_splits=N, shuffle=True, random_state=0)
    fold = 1
    models = {}

    for train_idx, valid_idx in skfold.split(features, features['num']):
        print('\n ================== sKFold {} =================='.format(fold))

        X_train, X_valid = features.iloc[train_idx, :], features.iloc[valid_idx, :]
        y_train, y_valid = labels.iloc[train_idx, :], labels.iloc[valid_idx, :]

        model = LGBMRegressor(n_estimators=10000, random_state=0)
        model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_valid, y_valid)], eval_metric= 'rmse', early_stopping_rounds=30, verbose=500)
        models[fold] = model
        
        pred = model.predict(X_valid)
        
        mae = mean_absolute_error(y_valid, pred)
        mse = mean_squared_error(y_valid, pred)
        rmse = np.sqrt(mean_squared_error(y_valid, pred))
        
        print('='*30)
        print('MAE: {0:.4f} \nMSE: {1:.4f} \nRMSE: {2:.4f}'.format(mae, mse, rmse))
        print('='*30)
        
        fold += 1
    
    return models

# %%
train, test, submission, features, labels = data_load(columns)
models = sKfold(train, 5)
# Out:
#  ================== sKFold 1 ==================
# Training until validation scores don't improve for 30 rounds
# [500]	training's rmse: 173.69	training's l2: 30168.3	valid_1's rmse: 210.902	valid_1's l2: 44479.5
# [1000]	training's rmse: 143.653	training's l2: 20636.1	valid_1's rmse: 197.576	valid_1's l2: 39036.4
# [1500]	training's rmse: 125.376	training's l2: 15719.1	valid_1's rmse: 191.488	valid_1's l2: 36667.5
# [2000]	training's rmse: 112.224	training's l2: 12594.3	valid_1's rmse: 187.661	valid_1's l2: 35216.8
# [2500]	training's rmse: 102.496	training's l2: 10505.5	valid_1's rmse: 185.366	valid_1's l2: 34360.6
# Early stopping, best iteration is:
# [2829]	training's rmse: 97.1903	training's l2: 9445.96	valid_1's rmse: 184.55	valid_1's l2: 34058.7
# ==============================
# MAE: 99.9892
# MSE: 34058.7068
# RMSE: 184.5500
# ==============================
#
#  ================== sKFold 2 ==================
# Training until validation scores don't improve for 30 rounds
# [500]	training's rmse: 171.586	training's l2: 29441.9	valid_1's rmse: 219.79	valid_1's l2: 48307.6
# [1000]	training's rmse: 141.764	training's l2: 20096.9	valid_1's rmse: 206.108	valid_1's l2: 42480.3
# [1500]	training's rmse: 124.253	training's l2: 15438.8	valid_1's rmse: 200.155	valid_1's l2: 40061.9
# [2000]	training's rmse: 111.713	training's l2: 12479.9	valid_1's rmse: 196.191	valid_1's l2: 38490.9
# [2500]	training's rmse: 102.057	training's l2: 10415.6	valid_1's rmse: 193.956	valid_1's l2: 37618.7
# [3000]	training's rmse: 94.4494	training's l2: 8920.7	valid_1's rmse: 192.256	valid_1's l2: 36962.5
# [3500]	training's rmse: 87.5745	training's l2: 7669.3	valid_1's rmse: 190.946	valid_1's l2: 36460.4
# [4000]	training's rmse: 81.5561	training's l2: 6651.4	valid_1's rmse: 189.992	valid_1's l2: 36096.8
# Early stopping, best iteration is:
# [4037]	training's rmse: 81.1609	training's l2: 6587.09	valid_1's rmse: 189.928	valid_1's l2: 36072.5
# ==============================
# MAE: 97.8186
# MSE: 36072.4824
# RMSE: 189.9276
# ==============================
#
#  ================== sKFold 3 ==================
# Training until validation scores don't improve for 30 rounds
# [500]	training's rmse: 173.687	training's l2: 30167.2	valid_1's rmse: 233.069	valid_1's l2: 54321.3
# [1000]	training's rmse: 142.098	training's l2: 20191.8	valid_1's rmse: 217.512	valid_1's l2: 47311.4
# [1500]	training's rmse: 123.944	training's l2: 15362.2	valid_1's rmse: 210.003	valid_1's l2: 44101.1
# [2000]	training's rmse: 111.824	training's l2: 12504.6	valid_1's rmse: 206.502	valid_1's l2: 42642.9
# [2500]	training's rmse: 102.079	training's l2: 10420.2	valid_1's rmse: 204.129	valid_1's l2: 41668.8
# [3000]	training's rmse: 93.9901	training's l2: 8834.14	valid_1's rmse: 202.323	valid_1's l2: 40934.8
# Early stopping, best iteration is:
# [3466]	training's rmse: 87.9215	training's l2: 7730.19	valid_1's rmse: 201.277	valid_1's l2: 40512.4
# ==============================
# MAE: 101.3422
# MSE: 40512.4407
# RMSE: 201.2770
# ==============================
#
#  ================== sKFold 4 ==================
# Training until validation scores don't improve for 30 rounds
# [500]	training's rmse: 172.571	training's l2: 29780.8	valid_1's rmse: 214.878	valid_1's l2: 46172.4
# [1000]	training's rmse: 142.419	training's l2: 20283.1	valid_1's rmse: 202.526	valid_1's l2: 41016.9
# [1500]	training's rmse: 125.352	training's l2: 15713.1	valid_1's rmse: 196.854	valid_1's l2: 38751.7
# [2000]	training's rmse: 112.164	training's l2: 12580.9	valid_1's rmse: 193.23	valid_1's l2: 37337.8
# [2500]	training's rmse: 102.269	training's l2: 10458.9	valid_1's rmse: 191.148	valid_1's l2: 36537.4
# [3000]	training's rmse: 94.5183	training's l2: 8933.7	valid_1's rmse: 189.527	valid_1's l2: 35920.7
# [3500]	training's rmse: 87.8035	training's l2: 7709.46	valid_1's rmse: 188.696	valid_1's l2: 35606.3
# Early stopping, best iteration is:
# [3470]	training's rmse: 88.2515	training's l2: 7788.33	valid_1's rmse: 188.663	valid_1's l2: 35593.6
# ==============================
# MAE: 99.1712
# MSE: 35593.5594
# RMSE: 188.6626
# ==============================
#
#  ================== sKFold 5 ==================
# Training until validation scores don't improve for 30 rounds
# [500]	training's rmse: 173.298	training's l2: 30032.1	valid_1's rmse: 206.664	valid_1's l2: 42710
# [1000]	training's rmse: 142.087	training's l2: 20188.7	valid_1's rmse: 193.069	valid_1's l2: 37275.5
# [1500]	training's rmse: 124.361	training's l2: 15465.7	valid_1's rmse: 187.545	valid_1's l2: 35173.2
# [2000]	training's rmse: 111.826	training's l2: 12505.1	valid_1's rmse: 184.525	valid_1's l2: 34049.4
# [2500]	training's rmse: 102.576	training's l2: 10521.7	valid_1's rmse: 182.06	valid_1's l2: 33146
# [3000]	training's rmse: 94.7917	training's l2: 8985.47	valid_1's rmse: 180.412	valid_1's l2: 32548.4
# [3500]	training's rmse: 88.3106	training's l2: 7798.76	valid_1's rmse: 179.476	valid_1's l2: 32211.8
# [4000]	training's rmse: 82.3658	training's l2: 6784.12	valid_1's rmse: 178.506	valid_1's l2: 31864.4
# Early stopping, best iteration is:
# [4060]	training's rmse: 81.685	training's l2: 6672.43	valid_1's rmse: 178.4	valid_1's l2: 31826.4
# ==============================
# MAE: 97.6225
# MSE: 31826.4218
# RMSE: 178.3996
# ==============================

# %% [markdown]
# ## RandomForest

# %%
def KfoldForest(train, N=None):
    kfold = KFold(n_splits=N, shuffle=True, random_state=0)
    fold = 1
    models = {}

    for train_idx, valid_idx in kfold.split(train):
        print('\n ================== Fold {} =================='.format(fold))

        X_train, X_valid = features.iloc[train_idx, :], features.iloc[valid_idx, :]
        y_train, y_valid = labels.iloc[train_idx, :], labels.iloc[valid_idx, :]
        
        
        model = RandomForestRegressor(random_state=0)
        model.fit(X_train, y_train)
        pred = model.predict(X_valid)
        
        mae = mean_absolute_error(y_valid, pred)
        mse = mean_squared_error(y_valid, pred)
        rmse = np.sqrt(mean_squared_error(y_valid, pred))
        
        print('MAE: {0:.4f} \nMSE: {1:.4f} \nRMSE: {2:.4f}'.format(mae, mse, rmse))
        
        models[fold] = model

        fold += 1
    
    return models

# %%
train, test, submission, features, labels = data_load(columns)
models = KfoldForest(train, 5)
# Out:
#  ================== Fold 1 ==================
# MAE: 121.1460
# MSE: 70082.4526
# RMSE: 264.7309
#
#  ================== Fold 2 ==================
# MAE: 118.6476
# MSE: 63287.0983
# RMSE: 251.5693
#
#  ================== Fold 3 ==================
# MAE: 119.4404
# MSE: 54014.8691
# RMSE: 232.4110
#
#  ================== Fold 4 ==================
# MAE: 117.9968
# MSE: 56927.5535
# RMSE: 238.5950
#
#  ================== Fold 5 ==================
# MAE: 118.4614
# MSE: 57056.5039
# RMSE: 238.8650

# %%
submission = pd.read_csv('energy/sample_submission.csv', encoding='cp949')

for i in range(1, 6):
    submission['answer'] += models[i].predict(test)/5

submission.to_csv('lgbm_day3_3.csv', index=False)
