# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

import xgboost as xgb
from lightgbm import LGBMRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

from sklearn.model_selection import KFold, StratifiedKFold, GridSearchCV, TimeSeriesSplit
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
columns = ['date_time']

# %%
def data_load(columns):
    train = pd.read_csv('edit_train.csv')
    test = pd.read_csv('edit_test.csv')
    submission = pd.read_csv('energy/sample_submission.csv', encoding='cp949')
    
    train = train.drop(columns, axis=1)
    test = test.drop(columns, axis=1)

    features = train.drop('전력사용량(kWh)', axis=1)
    labels = train[['전력사용량(kWh)']]
    
    return train, test, submission, features, labels

# %%
def lgbm_sKfold(train, N=None):
    skfold = StratifiedKFold(n_splits=N, shuffle=True, random_state=0)
    fold = 1
    models = {}

    for train_idx, valid_idx in skfold.split(features, features['num']):
        print('\n ================== sKFold {} =================='.format(fold))

        X_train, X_valid = features.iloc[train_idx, :], features.iloc[valid_idx, :]
        y_train, y_valid = labels.iloc[train_idx, :], labels.iloc[valid_idx, :]

        model = LGBMRegressor(n_estimators=10000, random_state=0)
        model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_valid, y_valid)], eval_metric= 'rmse', early_stopping_rounds=50, verbose=500)
        models[fold] = model
        
        pred = model.predict(X_valid)
        
        mae = mean_absolute_error(y_valid, pred)
        mse = mean_squared_error(y_valid, pred)
        rmse = np.sqrt(mean_squared_error(y_valid, pred))
        
        print('='*30)
        print('MAE: {0:.4f} \nMSE: {1:.4f} \nRMSE: {2:.4f}'.format(mae, mse, rmse))
        print('='*30)
        
        fold += 1
    
    return models

# %%
def xgb_sKfold(train, N=None):
    skfold = StratifiedKFold(n_splits=N, shuffle=True, random_state=0)
    fold = 1
    models = {}

    for train_idx, valid_idx in skfold.split(features, features['num']):
        print('\n ================== sKFold {} =================='.format(fold))

        X_train, X_valid = features.iloc[train_idx, :], features.iloc[valid_idx, :]
        y_train, y_valid = labels.iloc[train_idx, :], labels.iloc[valid_idx, :]

        model = xgb.XGBRegressor(n_estimators=10000, random_state=0)
        model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_valid, y_valid)], eval_metric= 'rmse', early_stopping_rounds=50, verbose=500)
        models[fold] = model
        
        pred = model.predict(X_valid)
        
        mae = mean_absolute_error(y_valid, pred)
        mse = mean_squared_error(y_valid, pred)
        rmse = np.sqrt(mean_squared_error(y_valid, pred))
        
        print('='*30)
        print('MAE: {0:.4f} \nMSE: {1:.4f} \nRMSE: {2:.4f}'.format(mae, mse, rmse))
        print('='*30)
        
        fold += 1
    
    return models

# %%
def rf_sKfold(train, N=None):
    skfold = StratifiedKFold(n_splits=N, shuffle=True, random_state=0)
    fold = 1
    models = {}

    for train_idx, valid_idx in skfold.split(features, features['num']):
        print('\n ================== sKFold {} =================='.format(fold))

        X_train, X_valid = features.iloc[train_idx, :], features.iloc[valid_idx, :]
        y_train, y_valid = labels.iloc[train_idx, :], labels.iloc[valid_idx, :]

        model = RandomForestRegressor(n_estimators=500, random_state=0)
        model.fit(X_train, y_train)
        pred = model.predict(X_valid)
        
        mae = mean_absolute_error(y_valid, pred)
        mse = mean_squared_error(y_valid, pred)
        rmse = np.sqrt(mean_squared_error(y_valid, pred))
        
        print('='*30)
        print('MAE: {0:.4f} \nMSE: {1:.4f} \nRMSE: {2:.4f}'.format(mae, mse, rmse))
        print('='*30)
        
        fold += 1
    
    return models

# %%
train, test, submission, features, labels = data_load(columns)
lgbm_models = sKfold(train, 5)
# Out:
#  ================== sKFold 1 ==================
# Training until validation scores don't improve for 50 rounds
# [500]	training's rmse: 168.879	training's l2: 28520	valid_1's rmse: 205.207	valid_1's l2: 42109.9
# [1000]	training's rmse: 137.899	training's l2: 19016.2	valid_1's rmse: 189.35	valid_1's l2: 35853.3
# [1500]	training's rmse: 119.709	training's l2: 14330.2	valid_1's rmse: 182.658	valid_1's l2: 33363.9
# [2000]	training's rmse: 107.247	training's l2: 11501.9	valid_1's rmse: 179.062	valid_1's l2: 32063.3
# [2500]	training's rmse: 98.2856	training's l2: 9660.05	valid_1's rmse: 176.774	valid_1's l2: 31248.9
# [3000]	training's rmse: 90.4979	training's l2: 8189.87	valid_1's rmse: 174.848	valid_1's l2: 30571.9
# [3500]	training's rmse: 83.698	training's l2: 7005.35	valid_1's rmse: 173.561	valid_1's l2: 30123.3
# [4000]	training's rmse: 77.9714	training's l2: 6079.54	valid_1's rmse: 172.541	valid_1's l2: 29770.5
# [4500]	training's rmse: 72.965	training's l2: 5323.89	valid_1's rmse: 171.711	valid_1's l2: 29484.7
# [5000]	training's rmse: 68.46	training's l2: 4686.78	valid_1's rmse: 171.159	valid_1's l2: 29295.4
# [5500]	training's rmse: 64.6285	training's l2: 4176.85	valid_1's rmse: 170.706	valid_1's l2: 29140.6
# Early stopping, best iteration is:
# [5726]	training's rmse: 63.0789	training's l2: 3978.95	valid_1's rmse: 170.5	valid_1's l2: 29070.4
# ==============================
# MAE: 91.9875
# MSE: 29070.4099
# RMSE: 170.5005
# ==============================
#
#  ================== sKFold 2 ==================
# Training until validation scores don't improve for 50 rounds
# [500]	training's rmse: 167.721	training's l2: 28130.3	valid_1's rmse: 207.802	valid_1's l2: 43181.8
# [1000]	training's rmse: 137.769	training's l2: 18980.4	valid_1's rmse: 193.875	valid_1's l2: 37587.3
# [1500]	training's rmse: 119.633	training's l2: 14312	valid_1's rmse: 186.255	valid_1's l2: 34690.8
# [2000]	training's rmse: 106.955	training's l2: 11439.4	valid_1's rmse: 182.248	valid_1's l2: 33214.5
# [2500]	training's rmse: 97.1832	training's l2: 9444.58	valid_1's rmse: 179.265	valid_1's l2: 32136.1
# [3000]	training's rmse: 89.3472	training's l2: 7982.93	valid_1's rmse: 177.429	valid_1's l2: 31480.9
# [3500]	training's rmse: 83.0557	training's l2: 6898.25	valid_1's rmse: 176.337	valid_1's l2: 31094.8
# [4000]	training's rmse: 77.6286	training's l2: 6026.2	valid_1's rmse: 175.28	valid_1's l2: 30722.9
# [4500]	training's rmse: 72.5464	training's l2: 5262.99	valid_1's rmse: 174.613	valid_1's l2: 30489.8
# [5000]	training's rmse: 68.1255	training's l2: 4641.08	valid_1's rmse: 173.979	valid_1's l2: 30268.6
# Early stopping, best iteration is:
# [5240]	training's rmse: 66.2329	training's l2: 4386.8	valid_1's rmse: 173.705	valid_1's l2: 30173.4
# ==============================
# MAE: 92.2554
# MSE: 30173.3690
# RMSE: 173.7048
# ==============================
#
#  ================== sKFold 3 ==================
# Training until validation scores don't improve for 50 rounds
# [500]	training's rmse: 166.335	training's l2: 27667.2	valid_1's rmse: 225.705	valid_1's l2: 50942.7
# [1000]	training's rmse: 136.263	training's l2: 18567.6	valid_1's rmse: 210.895	valid_1's l2: 44476.8
# [1500]	training's rmse: 118.372	training's l2: 14011.9	valid_1's rmse: 203.688	valid_1's l2: 41488.9
# [2000]	training's rmse: 105.83	training's l2: 11200	valid_1's rmse: 199.557	valid_1's l2: 39822.9
# [2500]	training's rmse: 96.4373	training's l2: 9300.16	valid_1's rmse: 196.711	valid_1's l2: 38695.1
# [3000]	training's rmse: 88.8433	training's l2: 7893.14	valid_1's rmse: 194.938	valid_1's l2: 38000.8
# [3500]	training's rmse: 82.2543	training's l2: 6765.77	valid_1's rmse: 193.642	valid_1's l2: 37497.3
# [4000]	training's rmse: 76.8402	training's l2: 5904.41	valid_1's rmse: 192.72	valid_1's l2: 37141.2
# [4500]	training's rmse: 72.0938	training's l2: 5197.52	valid_1's rmse: 191.719	valid_1's l2: 36756.1
# [5000]	training's rmse: 67.8159	training's l2: 4598.99	valid_1's rmse: 191.105	valid_1's l2: 36521.2
# [5500]	training's rmse: 64.2039	training's l2: 4122.14	valid_1's rmse: 190.534	valid_1's l2: 36303.2
# [6000]	training's rmse: 60.7084	training's l2: 3685.5	valid_1's rmse: 190.051	valid_1's l2: 36119.5
# [6500]	training's rmse: 57.492	training's l2: 3305.33	valid_1's rmse: 189.678	valid_1's l2: 35977.8
# [7000]	training's rmse: 54.5055	training's l2: 2970.85	valid_1's rmse: 189.305	valid_1's l2: 35836.5
# [7500]	training's rmse: 51.9552	training's l2: 2699.34	valid_1's rmse: 189	valid_1's l2: 35721
# Early stopping, best iteration is:
# [7885]	training's rmse: 50.1158	training's l2: 2511.59	valid_1's rmse: 188.852	valid_1's l2: 35665.2
# ==============================
# MAE: 93.2347
# MSE: 35665.1530
# RMSE: 188.8522
# ==============================
#
#  ================== sKFold 4 ==================
# Training until validation scores don't improve for 50 rounds
# [500]	training's rmse: 166.779	training's l2: 27815.2	valid_1's rmse: 212.093	valid_1's l2: 44983.6
# [1000]	training's rmse: 137.061	training's l2: 18785.7	valid_1's rmse: 198.974	valid_1's l2: 39590.8
# [1500]	training's rmse: 118.93	training's l2: 14144.3	valid_1's rmse: 192.533	valid_1's l2: 37069
# [2000]	training's rmse: 106.524	training's l2: 11347.3	valid_1's rmse: 189.126	valid_1's l2: 35768.7
# [2500]	training's rmse: 97.1689	training's l2: 9441.8	valid_1's rmse: 187.106	valid_1's l2: 35008.6
# [3000]	training's rmse: 89.4799	training's l2: 8006.66	valid_1's rmse: 185.231	valid_1's l2: 34310.5
# [3500]	training's rmse: 82.9845	training's l2: 6886.42	valid_1's rmse: 183.857	valid_1's l2: 33803.5
# [4000]	training's rmse: 77.0117	training's l2: 5930.81	valid_1's rmse: 182.811	valid_1's l2: 33419.9
# [4500]	training's rmse: 72.3959	training's l2: 5241.16	valid_1's rmse: 182.173	valid_1's l2: 33187
# [5000]	training's rmse: 68.0927	training's l2: 4636.61	valid_1's rmse: 181.611	valid_1's l2: 32982.6
# Early stopping, best iteration is:
# [5342]	training's rmse: 65.3977	training's l2: 4276.86	valid_1's rmse: 181.333	valid_1's l2: 32881.6
# ==============================
# MAE: 91.9300
# MSE: 32881.6386
# RMSE: 181.3329
# ==============================
#
#  ================== sKFold 5 ==================
# Training until validation scores don't improve for 50 rounds
# [500]	training's rmse: 169.679	training's l2: 28790.8	valid_1's rmse: 200.76	valid_1's l2: 40304.5
# [1000]	training's rmse: 137.761	training's l2: 18978.1	valid_1's rmse: 185.842	valid_1's l2: 34537.3
# [1500]	training's rmse: 119.687	training's l2: 14325	valid_1's rmse: 179.011	valid_1's l2: 32045.1
# [2000]	training's rmse: 107.344	training's l2: 11522.7	valid_1's rmse: 175.502	valid_1's l2: 30801.1
# [2500]	training's rmse: 97.5736	training's l2: 9520.6	valid_1's rmse: 173.155	valid_1's l2: 29982.8
# [3000]	training's rmse: 89.93	training's l2: 8087.4	valid_1's rmse: 171.481	valid_1's l2: 29405.6
# [3500]	training's rmse: 83.5276	training's l2: 6976.86	valid_1's rmse: 170.388	valid_1's l2: 29032
# [4000]	training's rmse: 77.7419	training's l2: 6043.81	valid_1's rmse: 169.329	valid_1's l2: 28672.1
# [4500]	training's rmse: 72.6373	training's l2: 5276.17	valid_1's rmse: 168.466	valid_1's l2: 28380.9
# [5000]	training's rmse: 68.1743	training's l2: 4647.73	valid_1's rmse: 167.851	valid_1's l2: 28173.8
# Early stopping, best iteration is:
# [5254]	training's rmse: 66.1123	training's l2: 4370.84	valid_1's rmse: 167.539	valid_1's l2: 28069.5
# ==============================
# MAE: 91.1622
# MSE: 28069.4776
# RMSE: 167.5395
# ==============================

# %%
train, test, submission, features, labels = data_load(columns)
xgb_models = xgb_sKfold(train, 5)
# Out:
#  ================== sKFold 1 ==================
# [0]	validation_0-rmse:2212.52759	validation_1-rmse:2201.59717
# [500]	validation_0-rmse:113.15136	validation_1-rmse:198.55585
# [1000]	validation_0-rmse:82.70358	validation_1-rmse:194.00102
# [1437]	validation_0-rmse:66.79118	validation_1-rmse:192.85071
# ==============================
# MAE: 106.3645
# MSE: 37173.9907
# RMSE: 192.8056
# ==============================
#
#  ================== sKFold 2 ==================
# [0]	validation_0-rmse:2208.79175	validation_1-rmse:2210.80420
# [500]	validation_0-rmse:114.07649	validation_1-rmse:210.87251
# [1000]	validation_0-rmse:82.37148	validation_1-rmse:205.96202
# [1382]	validation_0-rmse:67.79047	validation_1-rmse:205.13373
# ==============================
# MAE: 108.2642
# MSE: 42057.2240
# RMSE: 205.0786
# ==============================
#
#  ================== sKFold 3 ==================
# [0]	validation_0-rmse:2208.20459	validation_1-rmse:2212.38550
# [500]	validation_0-rmse:113.83881	validation_1-rmse:222.46339
# [1000]	validation_0-rmse:82.66311	validation_1-rmse:216.94667
# [1500]	validation_0-rmse:63.81551	validation_1-rmse:215.14682
# [1592]	validation_0-rmse:61.61703	validation_1-rmse:215.08632
# ==============================
# MAE: 110.9533
# MSE: 46235.2086
# RMSE: 215.0237
# ==============================
#
#  ================== sKFold 4 ==================
# [0]	validation_0-rmse:2207.89233	validation_1-rmse:2217.92895
# [500]	validation_0-rmse:114.16308	validation_1-rmse:211.57350
# [1000]	validation_0-rmse:83.23406	validation_1-rmse:207.39867
# [1500]	validation_0-rmse:65.10535	validation_1-rmse:206.07088
# [1613]	validation_0-rmse:61.64544	validation_1-rmse:206.01623
# ==============================
# MAE: 107.9378
# MSE: 42428.1139
# RMSE: 205.9809
# ==============================
#
#  ================== sKFold 5 ==================
# [0]	validation_0-rmse:2209.94238	validation_1-rmse:2209.13867
# [500]	validation_0-rmse:114.31900	validation_1-rmse:196.09711
# [1000]	validation_0-rmse:83.17896	validation_1-rmse:192.48981
# [1004]	validation_0-rmse:83.03902	validation_1-rmse:192.46864
# ==============================
# MAE: 107.3740
# MSE: 36994.3615
# RMSE: 192.3392
# ==============================

# %%
train, test, submission, features, labels = data_load(columns)
rf_models = rf_sKfold(train, 5)
# Out:
#  ================== sKFold 1 ==================
# ==============================
# MAE: 115.3020
# MSE: 58696.9433
# RMSE: 242.2745
# ==============================
#
#  ================== sKFold 2 ==================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-68-c07e5bb0e8f4> in <module>
#       1 train, test, submission, features, labels = data_load(columns)
# ----> 2 rf_models = rf_sKfold(train, 5)
#
# <ipython-input-67-d9dbaa593595> in rf_sKfold(train, N)
#      11
#      12         model = RandomForestRegressor(n_estimators=1000, random_state=0)
# ---> 13         model.fit(X_train, y_train)
#      14         pred = model.predict(X_valid)
#      15
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     384             # parallel_backend contexts set at a higher level,
#     385             # since correctness does not rely on using threads.
# --> 386             trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#     387                              **_joblib_parallel_args(prefer='threads'))(
#     388                 delayed(_parallel_build_trees)(
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1049                 self._iterating = self._original_iterator is not None
#    1050
# -> 1051             while self.dispatch_one_batch(iterator):
#    1052                 pass
#    1053
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     166                                                         indices=indices)
#     167
# --> 168         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     169     else:
#     170         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1240         """
#    1241
# -> 1242         super().fit(
#    1243             X, y,
#    1244             sample_weight=sample_weight,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     373                                            min_impurity_split)
#     374
# --> 375         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     376
#     377         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %%
submission = pd.read_csv('energy/sample_submission.csv', encoding='cp949')

for i in range(1, 6):
#     submission['answer'] += lgbm_models[i].predict(test)/5
    submission['answer'] += xgb_models[i].predict(test)/5
#     submission['answer'] += rf_models[i].predict(test)/15
    
submission.to_csv('lgbm_day6_3.csv', index=False)
