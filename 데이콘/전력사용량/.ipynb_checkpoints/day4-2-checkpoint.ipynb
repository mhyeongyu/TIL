# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor


from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
# train = pd.read_csv('edit_train.csv')
# test = pd.read_csv('edit_test.csv')
# submission = pd.read_csv('energy/sample_submission.csv', encoding='cp949')

# %%
def data_load(columns):
    train = pd.read_csv('edit_train.csv')
    test = pd.read_csv('edit_test.csv')
    submission = pd.read_csv('energy/sample_submission.csv', encoding='cp949')
    
    train = train.drop(columns, axis=1)
    test = test.drop(columns, axis=1)

    features = train.drop('전력사용량(kWh)', axis=1)
    labels = train[['전력사용량(kWh)']]
    
    return train, test, submission, features, labels

# %% [markdown]
# ## KFold

# %%
def Kfold(train, N=None):
    kfold = KFold(n_splits=N, shuffle=True, random_state=0)
    fold = 1
    models = {}

    for train_idx, valid_idx in kfold.split(train):
        print('\n ================== Fold {} =================='.format(fold))

        X_train, X_valid = features.iloc[train_idx, :], features.iloc[valid_idx, :]
        y_train, y_valid = labels.iloc[train_idx, :], labels.iloc[valid_idx, :]

        model = LGBMRegressor(n_estimators=10000, random_state=0)
        model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_valid, y_valid)], eval_metric= 'rmse', early_stopping_rounds=100, verbose=500)
        models[fold] = model
        
        pred = model.predict(X_valid)
        
        mae = mean_absolute_error(y_valid, pred)
        mse = mean_squared_error(y_valid, pred)
        rmse = np.sqrt(mean_squared_error(y_valid, pred))
        
        print('='*30)
        print('MAE: {0:.4f} \nMSE: {1:.4f} \nRMSE: {2:.4f}'.format(mae, mse, rmse))
        print('='*30)
        
        fold += 1
    
    return models

# %%
train.columns
# Out:
# Index(['num', '전력사용량(kWh)', '기온(°C)', '풍속(m/s)', '습도(%)', '강수량(mm)', '일조(hr)',
#        '비전기냉방설비운영', '태양광보유', 'hour', 'weekday', 'holiday',
#        'perceived_temperature', 'discomfort_index', 'ref_day',
#        'hour_assignment', 'gmm_num_assignment'],
#       dtype='object')

# %%
columns = ['date_time']

train, test, submission, features, labels = data_load(columns)
models = Kfold(train, 5)
# Out:
#  ================== Fold 1 ==================
# Training until validation scores don't improve for 100 rounds
# [500]	training's rmse: 181.166	training's l2: 32821.3	valid_1's rmse: 205.574	valid_1's l2: 42260.5
# [1000]	training's rmse: 146.075	training's l2: 21337.8	valid_1's rmse: 186.351	valid_1's l2: 34726.6
# [1500]	training's rmse: 125.686	training's l2: 15797	valid_1's rmse: 178.099	valid_1's l2: 31719.3
# [2000]	training's rmse: 112.176	training's l2: 12583.4	valid_1's rmse: 173.976	valid_1's l2: 30267.7
# [2500]	training's rmse: 101.763	training's l2: 10355.8	valid_1's rmse: 171.439	valid_1's l2: 29391.2
# [3000]	training's rmse: 93.2564	training's l2: 8696.76	valid_1's rmse: 169.576	valid_1's l2: 28756
# [3500]	training's rmse: 86.0226	training's l2: 7399.89	valid_1's rmse: 168.24	valid_1's l2: 28304.5
# [4000]	training's rmse: 80.1308	training's l2: 6420.95	valid_1's rmse: 167.354	valid_1's l2: 28007.3
# [4500]	training's rmse: 74.5037	training's l2: 5550.8	valid_1's rmse: 166.63	valid_1's l2: 27765.6
# [5000]	training's rmse: 69.6434	training's l2: 4850.2	valid_1's rmse: 165.925	valid_1's l2: 27531.1
# [5500]	training's rmse: 65.6163	training's l2: 4305.49	valid_1's rmse: 165.478	valid_1's l2: 27383
# [6000]	training's rmse: 61.8395	training's l2: 3824.13	valid_1's rmse: 165.061	valid_1's l2: 27245.2
# [6500]	training's rmse: 58.5617	training's l2: 3429.47	valid_1's rmse: 164.868	valid_1's l2: 27181.3
# [7000]	training's rmse: 55.4801	training's l2: 3078.05	valid_1's rmse: 164.636	valid_1's l2: 27105.1
# [7500]	training's rmse: 52.5238	training's l2: 2758.75	valid_1's rmse: 164.383	valid_1's l2: 27021.9
# [8000]	training's rmse: 49.8246	training's l2: 2482.49	valid_1's rmse: 164.143	valid_1's l2: 26942.8
# [8500]	training's rmse: 47.3888	training's l2: 2245.7	valid_1's rmse: 163.935	valid_1's l2: 26874.7
# [9000]	training's rmse: 45.0688	training's l2: 2031.19	valid_1's rmse: 163.78	valid_1's l2: 26823.9
# [9500]	training's rmse: 43.0291	training's l2: 1851.5	valid_1's rmse: 163.643	valid_1's l2: 26779
# Early stopping, best iteration is:
# [9573]	training's rmse: 42.7073	training's l2: 1823.91	valid_1's rmse: 163.597	valid_1's l2: 26763.9
# ==============================
# MAE: 96.4189
# MSE: 26763.9143
# RMSE: 163.5968
# ==============================
#
#  ================== Fold 2 ==================
# Training until validation scores don't improve for 100 rounds
# [500]	training's rmse: 176.242	training's l2: 31061.1	valid_1's rmse: 241.776	valid_1's l2: 58455.5
# [1000]	training's rmse: 143.139	training's l2: 20488.8	valid_1's rmse: 225.317	valid_1's l2: 50767.7
# [1500]	training's rmse: 123.846	training's l2: 15337.7	valid_1's rmse: 216.312	valid_1's l2: 46791
# [2000]	training's rmse: 110.365	training's l2: 12180.5	valid_1's rmse: 212.488	valid_1's l2: 45151.2
# [2500]	training's rmse: 100.497	training's l2: 10099.6	valid_1's rmse: 210.506	valid_1's l2: 44312.7
# [3000]	training's rmse: 92.0409	training's l2: 8471.53	valid_1's rmse: 208.336	valid_1's l2: 43403.7
# [3500]	training's rmse: 84.435	training's l2: 7129.27	valid_1's rmse: 206.721	valid_1's l2: 42733.7
# [4000]	training's rmse: 78.8175	training's l2: 6212.2	valid_1's rmse: 205.812	valid_1's l2: 42358.7
# [4500]	training's rmse: 73.9593	training's l2: 5469.98	valid_1's rmse: 204.856	valid_1's l2: 41965.9
# [5000]	training's rmse: 69.1306	training's l2: 4779.04	valid_1's rmse: 204.029	valid_1's l2: 41627.9
# [5500]	training's rmse: 64.6634	training's l2: 4181.35	valid_1's rmse: 203.135	valid_1's l2: 41263.8
# [6000]	training's rmse: 60.8046	training's l2: 3697.2	valid_1's rmse: 202.748	valid_1's l2: 41106.9
# Early stopping, best iteration is:
# [5921]	training's rmse: 61.3547	training's l2: 3764.4	valid_1's rmse: 202.715	valid_1's l2: 41093.3
# ==============================
# MAE: 100.8253
# MSE: 41093.3201
# RMSE: 202.7149
# ==============================
#
#  ================== Fold 3 ==================
# Training until validation scores don't improve for 100 rounds
# [500]	training's rmse: 178.72	training's l2: 31941	valid_1's rmse: 204.336	valid_1's l2: 41753.4
# [1000]	training's rmse: 144.479	training's l2: 20874	valid_1's rmse: 185.47	valid_1's l2: 34399.2
# [1500]	training's rmse: 125.548	training's l2: 15762.3	valid_1's rmse: 177.821	valid_1's l2: 31620.5
# [2000]	training's rmse: 111.951	training's l2: 12532.9	valid_1's rmse: 173.767	valid_1's l2: 30195.1
# [2500]	training's rmse: 101.377	training's l2: 10277.2	valid_1's rmse: 171.045	valid_1's l2: 29256.5
# [3000]	training's rmse: 93.3265	training's l2: 8709.83	valid_1's rmse: 169.251	valid_1's l2: 28645.8
# [3500]	training's rmse: 86.3418	training's l2: 7454.91	valid_1's rmse: 167.756	valid_1's l2: 28142.2
# [4000]	training's rmse: 79.9189	training's l2: 6387.03	valid_1's rmse: 166.602	valid_1's l2: 27756.3
# [4500]	training's rmse: 74.3364	training's l2: 5525.9	valid_1's rmse: 165.702	valid_1's l2: 27457.3
# [5000]	training's rmse: 69.4835	training's l2: 4827.96	valid_1's rmse: 164.996	valid_1's l2: 27223.7
# [5500]	training's rmse: 65.4484	training's l2: 4283.49	valid_1's rmse: 164.45	valid_1's l2: 27043.7
# [6000]	training's rmse: 61.6561	training's l2: 3801.47	valid_1's rmse: 164.143	valid_1's l2: 26943
# [6500]	training's rmse: 58.2135	training's l2: 3388.81	valid_1's rmse: 163.72	valid_1's l2: 26804.3
# [7000]	training's rmse: 55.1523	training's l2: 3041.78	valid_1's rmse: 163.427	valid_1's l2: 26708.4
# [7500]	training's rmse: 52.1006	training's l2: 2714.48	valid_1's rmse: 163.198	valid_1's l2: 26633.5
# [8000]	training's rmse: 49.5776	training's l2: 2457.94	valid_1's rmse: 162.987	valid_1's l2: 26564.7
# [8500]	training's rmse: 47.0158	training's l2: 2210.48	valid_1's rmse: 162.715	valid_1's l2: 26476.1
# Early stopping, best iteration is:
# [8762]	training's rmse: 45.6568	training's l2: 2084.54	valid_1's rmse: 162.615	valid_1's l2: 26443.6
# ==============================
# MAE: 97.0064
# MSE: 26443.6333
# RMSE: 162.6150
# ==============================
#
#  ================== Fold 4 ==================
# Training until validation scores don't improve for 100 rounds
# [500]	training's rmse: 177.633	training's l2: 31553.4	valid_1's rmse: 208.784	valid_1's l2: 43590.6
# [1000]	training's rmse: 142.893	training's l2: 20418.3	valid_1's rmse: 189.991	valid_1's l2: 36096.6
# [1500]	training's rmse: 124.546	training's l2: 15511.7	valid_1's rmse: 183.102	valid_1's l2: 33526.3
# [2000]	training's rmse: 110.816	training's l2: 12280.2	valid_1's rmse: 178.111	valid_1's l2: 31723.7
# [2500]	training's rmse: 101.303	training's l2: 10262.3	valid_1's rmse: 175.541	valid_1's l2: 30814.5
# [3000]	training's rmse: 92.9854	training's l2: 8646.28	valid_1's rmse: 173.468	valid_1's l2: 30091.3
# [3500]	training's rmse: 86.2471	training's l2: 7438.56	valid_1's rmse: 172.188	valid_1's l2: 29648.9
# [4000]	training's rmse: 80.6978	training's l2: 6512.13	valid_1's rmse: 171.476	valid_1's l2: 29403.9
# [4500]	training's rmse: 75.3206	training's l2: 5673.2	valid_1's rmse: 170.619	valid_1's l2: 29110.8
# [5000]	training's rmse: 70.5492	training's l2: 4977.19	valid_1's rmse: 169.909	valid_1's l2: 28869.1
# [5500]	training's rmse: 66.376	training's l2: 4405.78	valid_1's rmse: 169.47	valid_1's l2: 28720.2
# [6000]	training's rmse: 62.3134	training's l2: 3882.96	valid_1's rmse: 168.815	valid_1's l2: 28498.6
# [6500]	training's rmse: 58.6991	training's l2: 3445.58	valid_1's rmse: 168.544	valid_1's l2: 28407
# [7000]	training's rmse: 55.399	training's l2: 3069.05	valid_1's rmse: 168.171	valid_1's l2: 28281.4
# [7500]	training's rmse: 52.3594	training's l2: 2741.5	valid_1's rmse: 167.897	valid_1's l2: 28189.5
# [8000]	training's rmse: 49.682	training's l2: 2468.3	valid_1's rmse: 167.712	valid_1's l2: 28127.3
# Early stopping, best iteration is:
# [8076]	training's rmse: 49.3076	training's l2: 2431.24	valid_1's rmse: 167.683	valid_1's l2: 28117.5
# ==============================
# MAE: 97.9372
# MSE: 28117.5032
# RMSE: 167.6827
# ==============================
#
#  ================== Fold 5 ==================
# Training until validation scores don't improve for 100 rounds
# [500]	training's rmse: 181.667	training's l2: 33002.8	valid_1's rmse: 209.634	valid_1's l2: 43946.3
# [1000]	training's rmse: 146.255	training's l2: 21390.6	valid_1's rmse: 189.373	valid_1's l2: 35862.2
# [1500]	training's rmse: 125.971	training's l2: 15868.6	valid_1's rmse: 180.547	valid_1's l2: 32597.3
# [2000]	training's rmse: 112.505	training's l2: 12657.5	valid_1's rmse: 176.73	valid_1's l2: 31233.5
# [2500]	training's rmse: 102.111	training's l2: 10426.7	valid_1's rmse: 174.151	valid_1's l2: 30328.7
# [3000]	training's rmse: 93.0187	training's l2: 8652.47	valid_1's rmse: 171.877	valid_1's l2: 29541.7
# [3500]	training's rmse: 85.6903	training's l2: 7342.83	valid_1's rmse: 170.572	valid_1's l2: 29094.7
# [4000]	training's rmse: 79.869	training's l2: 6379.05	valid_1's rmse: 169.703	valid_1's l2: 28799.2
# [4500]	training's rmse: 74.4027	training's l2: 5535.77	valid_1's rmse: 169.019	valid_1's l2: 28567.5
# [5000]	training's rmse: 69.824	training's l2: 4875.38	valid_1's rmse: 168.414	valid_1's l2: 28363.4
# [5500]	training's rmse: 65.7009	training's l2: 4316.61	valid_1's rmse: 168.052	valid_1's l2: 28241.4
# [6000]	training's rmse: 61.9405	training's l2: 3836.62	valid_1's rmse: 167.747	valid_1's l2: 28139.1
# [6500]	training's rmse: 58.413	training's l2: 3412.08	valid_1's rmse: 167.363	valid_1's l2: 28010.2
# [7000]	training's rmse: 55.0602	training's l2: 3031.62	valid_1's rmse: 167.082	valid_1's l2: 27916.5
# [7500]	training's rmse: 52.1931	training's l2: 2724.12	valid_1's rmse: 166.878	valid_1's l2: 27848.2
# Early stopping, best iteration is:
# [7506]	training's rmse: 52.1609	training's l2: 2720.76	valid_1's rmse: 166.875	valid_1's l2: 27847.4
# ==============================
# MAE: 99.1118
# MSE: 27847.3685
# RMSE: 166.8753
# ==============================

# %% [markdown]
# ## StratifiedKFold

# %%
def sKfold(train, N=None):
    skfold = StratifiedKFold(n_splits=N, shuffle=True, random_state=0)
    fold = 1
    models = {}

    for train_idx, valid_idx in skfold.split(features, features['num']):
        print('\n ================== sKFold {} =================='.format(fold))

        X_train, X_valid = features.iloc[train_idx, :], features.iloc[valid_idx, :]
        y_train, y_valid = labels.iloc[train_idx, :], labels.iloc[valid_idx, :]

        model = LGBMRegressor(n_estimators=10000, random_state=0)
        model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_valid, y_valid)], eval_metric= 'rmse', early_stopping_rounds=30, verbose=500)
        models[fold] = model
        
        pred = model.predict(X_valid)
        
        mae = mean_absolute_error(y_valid, pred)
        mse = mean_squared_error(y_valid, pred)
        rmse = np.sqrt(mean_squared_error(y_valid, pred))
        
        print('='*30)
        print('MAE: {0:.4f} \nMSE: {1:.4f} \nRMSE: {2:.4f}'.format(mae, mse, rmse))
        print('='*30)
        
        fold += 1
    
    return models

# %%
train, test, submission, features, labels = data_load(columns)
models = sKfold(train, 5)
# Out:
#  ================== sKFold 1 ==================
# Training until validation scores don't improve for 30 rounds
# [500]	training's rmse: 179.894	training's l2: 32362	valid_1's rmse: 208.694	valid_1's l2: 43553.4
# [1000]	training's rmse: 145.059	training's l2: 21042.2	valid_1's rmse: 189.995	valid_1's l2: 36098.2
# [1500]	training's rmse: 125.867	training's l2: 15842.6	valid_1's rmse: 182.954	valid_1's l2: 33472
# [2000]	training's rmse: 112.119	training's l2: 12570.7	valid_1's rmse: 179.164	valid_1's l2: 32099.8
# [2500]	training's rmse: 101.415	training's l2: 10285.1	valid_1's rmse: 176.552	valid_1's l2: 31170.8
# [3000]	training's rmse: 92.4616	training's l2: 8549.15	valid_1's rmse: 174.333	valid_1's l2: 30391.8
# Early stopping, best iteration is:
# [3335]	training's rmse: 87.8491	training's l2: 7717.47	valid_1's rmse: 173.683	valid_1's l2: 30165.7
# ==============================
# MAE: 101.9673
# MSE: 30165.6612
# RMSE: 173.6826
# ==============================
#
#  ================== sKFold 2 ==================
# Training until validation scores don't improve for 30 rounds
# [500]	training's rmse: 177.604	training's l2: 31543	valid_1's rmse: 202.433	valid_1's l2: 40979.1
# [1000]	training's rmse: 144.096	training's l2: 20763.5	valid_1's rmse: 185.177	valid_1's l2: 34290.7
# [1500]	training's rmse: 125.678	training's l2: 15795	valid_1's rmse: 178.054	valid_1's l2: 31703.3
# [2000]	training's rmse: 111.883	training's l2: 12517.7	valid_1's rmse: 172.985	valid_1's l2: 29923.8
# [2500]	training's rmse: 101.789	training's l2: 10361	valid_1's rmse: 170.863	valid_1's l2: 29194.1
# [3000]	training's rmse: 93.2167	training's l2: 8689.36	valid_1's rmse: 168.796	valid_1's l2: 28492.2
# [3500]	training's rmse: 86.3733	training's l2: 7460.34	valid_1's rmse: 167.383	valid_1's l2: 28017
# [4000]	training's rmse: 80.076	training's l2: 6412.16	valid_1's rmse: 166.067	valid_1's l2: 27578.4
# [4500]	training's rmse: 74.5225	training's l2: 5553.6	valid_1's rmse: 165.145	valid_1's l2: 27272.9
# [5000]	training's rmse: 69.6567	training's l2: 4852.06	valid_1's rmse: 164.492	valid_1's l2: 27057.7
# Early stopping, best iteration is:
# [5258]	training's rmse: 67.6264	training's l2: 4573.33	valid_1's rmse: 164.271	valid_1's l2: 26985.1
# ==============================
# MAE: 98.0759
# MSE: 26985.0561
# RMSE: 164.2713
# ==============================
#
#  ================== sKFold 3 ==================
# Training until validation scores don't improve for 30 rounds
# [500]	training's rmse: 179.785	training's l2: 32322.5	valid_1's rmse: 211.718	valid_1's l2: 44824.4
# [1000]	training's rmse: 145.173	training's l2: 21075.2	valid_1's rmse: 192.276	valid_1's l2: 36970.2
# [1500]	training's rmse: 126.14	training's l2: 15911.2	valid_1's rmse: 185.1	valid_1's l2: 34261.9
# [2000]	training's rmse: 113.08	training's l2: 12787.1	valid_1's rmse: 180.969	valid_1's l2: 32749.7
# [2500]	training's rmse: 101.911	training's l2: 10385.9	valid_1's rmse: 177.98	valid_1's l2: 31676.8
# [3000]	training's rmse: 93.6233	training's l2: 8765.33	valid_1's rmse: 176.122	valid_1's l2: 31019.1
# [3500]	training's rmse: 85.8965	training's l2: 7378.21	valid_1's rmse: 174.834	valid_1's l2: 30566.9
# Early stopping, best iteration is:
# [3665]	training's rmse: 83.8296	training's l2: 7027.41	valid_1's rmse: 174.49	valid_1's l2: 30446.8
# ==============================
# MAE: 100.8640
# MSE: 30446.7812
# RMSE: 174.4901
# ==============================
#
#  ================== sKFold 4 ==================
# Training until validation scores don't improve for 30 rounds
# [500]	training's rmse: 177.918	training's l2: 31654.9	valid_1's rmse: 202.096	valid_1's l2: 40842.8
# [1000]	training's rmse: 145.537	training's l2: 21181	valid_1's rmse: 186.051	valid_1's l2: 34615
# [1500]	training's rmse: 125.44	training's l2: 15735.1	valid_1's rmse: 177.389	valid_1's l2: 31466.7
# [2000]	training's rmse: 111.225	training's l2: 12371	valid_1's rmse: 172.669	valid_1's l2: 29814.5
# [2500]	training's rmse: 100.575	training's l2: 10115.3	valid_1's rmse: 170.11	valid_1's l2: 28937.3
# Early stopping, best iteration is:
# [2675]	training's rmse: 97.5456	training's l2: 9515.13	valid_1's rmse: 169.443	valid_1's l2: 28711
# ==============================
# MAE: 102.8344
# MSE: 28711.0253
# RMSE: 169.4433
# ==============================
#
#  ================== sKFold 5 ==================
# Training until validation scores don't improve for 30 rounds
# [500]	training's rmse: 177.89	training's l2: 31644.9	valid_1's rmse: 231.982	valid_1's l2: 53815.4
# [1000]	training's rmse: 142.897	training's l2: 20419.6	valid_1's rmse: 214.859	valid_1's l2: 46164.5
# [1500]	training's rmse: 124.809	training's l2: 15577.4	valid_1's rmse: 208.349	valid_1's l2: 43409.1
# [2000]	training's rmse: 110.846	training's l2: 12286.8	valid_1's rmse: 204.481	valid_1's l2: 41812.5
# [2500]	training's rmse: 100.681	training's l2: 10136.6	valid_1's rmse: 202.115	valid_1's l2: 40850.4
# Early stopping, best iteration is:
# [2832]	training's rmse: 95.4611	training's l2: 9112.81	valid_1's rmse: 201.293	valid_1's l2: 40519
# ==============================
# MAE: 104.4415
# MSE: 40518.9845
# RMSE: 201.2933
# ==============================

# %% [markdown]
# ## RandomForest

# %%
def KfoldForest(train, N=None):
    kfold = KFold(n_splits=N, shuffle=True, random_state=0)
    fold = 1
    models = {}

    for train_idx, valid_idx in kfold.split(train):
        print('\n ================== Fold {} =================='.format(fold))

        X_train, X_valid = features.iloc[train_idx, :], features.iloc[valid_idx, :]
        y_train, y_valid = labels.iloc[train_idx, :], labels.iloc[valid_idx, :]
        
        
        model = RandomForestRegressor(random_state=0)
        model.fit(X_train, y_train)
        pred = model.predict(X_valid)
        
        mae = mean_absolute_error(y_valid, pred)
        mse = mean_squared_error(y_valid, pred)
        rmse = np.sqrt(mean_squared_error(y_valid, pred))
        
        print('MAE: {0:.4f} \nMSE: {1:.4f} \nRMSE: {2:.4f}'.format(mae, mse, rmse))
        
        models[fold] = model

        fold += 1
    
    return models

# %%
train, test, submission, features, labels = data_load(columns)
models = KfoldForest(train, 5)
# Out:
#  ================== Fold 1 ==================
# MAE: 88.9583
# MSE: 32198.0299
# RMSE: 179.4381
#
#  ================== Fold 2 ==================
# MAE: 94.4796
# MSE: 48452.1476
# RMSE: 220.1185
#
#  ================== Fold 3 ==================
# MAE: 91.2638
# MSE: 31570.0613
# RMSE: 177.6797
#
#  ================== Fold 4 ==================
# MAE: 89.8084
# MSE: 35248.1979
# RMSE: 187.7450
#
#  ================== Fold 5 ==================
# MAE: 89.8402
# MSE: 30111.9460
# RMSE: 173.5279

# %%
def xgb_Kfold(train, N=None):
    kfold = KFold(n_splits=N, shuffle=True, random_state=0)
    fold = 1
    models = {}

    for train_idx, valid_idx in kfold.split(train):
        print('\n ================== Fold {} =================='.format(fold))

        X_train, X_valid = features.iloc[train_idx, :], features.iloc[valid_idx, :]
        y_train, y_valid = labels.iloc[train_idx, :], labels.iloc[valid_idx, :]

        model = XGBRegressor(n_estimators=10000, random_state=0)
        model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_valid, y_valid)], eval_metric= 'rmse', early_stopping_rounds=100, verbose=500)
        models[fold] = model
        
        pred = model.predict(X_valid)
        
        mae = mean_absolute_error(y_valid, pred)
        mse = mean_squared_error(y_valid, pred)
        rmse = np.sqrt(mean_squared_error(y_valid, pred))
        
        print('='*30)
        print('MAE: {0:.4f} \nMSE: {1:.4f} \nRMSE: {2:.4f}'.format(mae, mse, rmse))
        print('='*30)
        
        fold += 1
    
    return models

# %%
columns = ['date_time']

train, test, submission, features, labels = data_load(columns)
models = xgb_Kfold(train, 5)
# Out:
#  ================== Fold 1 ==================
# [0]	validation_0-rmse:2247.24927	validation_1-rmse:2256.78711
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [500]	validation_0-rmse:130.78369	validation_1-rmse:206.19284
# [1000]	validation_0-rmse:93.39452	validation_1-rmse:200.37775
# [1500]	validation_0-rmse:72.16432	validation_1-rmse:198.74883
# [2000]	validation_0-rmse:56.46673	validation_1-rmse:197.77647
# [2500]	validation_0-rmse:45.91515	validation_1-rmse:197.36523
# Stopping. Best iteration:
# [2584]	validation_0-rmse:44.43705	validation_1-rmse:197.33546
#
# ==============================
# MAE: 121.0998
# MSE: 38941.2813
# RMSE: 197.3355
# ==============================
#
#  ================== Fold 2 ==================
# [0]	validation_0-rmse:2252.35083	validation_1-rmse:2230.90405
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [500]	validation_0-rmse:128.20734	validation_1-rmse:238.43959
# [1000]	validation_0-rmse:92.28738	validation_1-rmse:233.85234
# [1500]	validation_0-rmse:70.87261	validation_1-rmse:232.57138
# Stopping. Best iteration:
# [1506]	validation_0-rmse:70.67091	validation_1-rmse:232.54906
#
# ==============================
# MAE: 126.8359
# MSE: 54079.0949
# RMSE: 232.5491
# ==============================
#
#  ================== Fold 3 ==================
# [0]	validation_0-rmse:2248.39136	validation_1-rmse:2251.20630
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [500]	validation_0-rmse:130.47286	validation_1-rmse:207.75856
# [1000]	validation_0-rmse:93.17286	validation_1-rmse:202.12131
# [1500]	validation_0-rmse:70.79185	validation_1-rmse:199.65045
# [2000]	validation_0-rmse:55.89424	validation_1-rmse:198.94388
# [2500]	validation_0-rmse:45.10571	validation_1-rmse:198.62952
# Stopping. Best iteration:
# [2508]	validation_0-rmse:44.93557	validation_1-rmse:198.60400
#
# ==============================
# MAE: 123.4963
# MSE: 39443.5514
# RMSE: 198.6040
# ==============================
#
#  ================== Fold 4 ==================
# [0]	validation_0-rmse:2247.48755	validation_1-rmse:2256.32690
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [500]	validation_0-rmse:129.82535	validation_1-rmse:212.80074
# [1000]	validation_0-rmse:93.10081	validation_1-rmse:205.24297
# Stopping. Best iteration:
# [1308]	validation_0-rmse:78.47314	validation_1-rmse:204.26180
#
# ==============================
# MAE: 125.5539
# MSE: 41722.8999
# RMSE: 204.2618
# ==============================
#
#  ================== Fold 5 ==================
# [0]	validation_0-rmse:2249.16528	validation_1-rmse:2250.07544
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [500]	validation_0-rmse:129.84109	validation_1-rmse:206.32675
# [1000]	validation_0-rmse:93.61327	validation_1-rmse:202.00946
# [1500]	validation_0-rmse:71.97168	validation_1-rmse:200.49417
# Stopping. Best iteration:
# [1866]	validation_0-rmse:60.09301	validation_1-rmse:199.68361
#
# ==============================
# MAE: 124.6804
# MSE: 39873.5473
# RMSE: 199.6836
# ==============================

# %%
def xgb_sKfold(train, N=None):
    skfold = StratifiedKFold(n_splits=N, shuffle=True, random_state=0)
    fold = 1
    models = {}

    for train_idx, valid_idx in skfold.split(features, features['num']):
        print('\n ================== sKFold {} =================='.format(fold))

        X_train, X_valid = features.iloc[train_idx, :], features.iloc[valid_idx, :]
        y_train, y_valid = labels.iloc[train_idx, :], labels.iloc[valid_idx, :]

        model = XGBRegressor(n_estimators=10000, random_state=0)
        model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_valid, y_valid)], eval_metric= 'rmse', early_stopping_rounds=30, verbose=500)
        models[fold] = model
        
        pred = model.predict(X_valid)
        
        mae = mean_absolute_error(y_valid, pred)
        mse = mean_squared_error(y_valid, pred)
        rmse = np.sqrt(mean_squared_error(y_valid, pred))
        
        print('='*30)
        print('MAE: {0:.4f} \nMSE: {1:.4f} \nRMSE: {2:.4f}'.format(mae, mse, rmse))
        print('='*30)
        
        fold += 1
    
    return models

# %%
train, test, submission, features, labels = data_load(columns)
models = xgb_sKfold(train, 5)

# %%
submission = pd.read_csv('energy/sample_submission.csv', encoding='cp949')

for i in range(1, 6):
    submission['answer'] += models[i].predict(test)/5

submission.to_csv('lgbm_day4_3.csv', index=False)
