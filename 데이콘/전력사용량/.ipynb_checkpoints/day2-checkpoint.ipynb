# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

from lightgbm import LGBMRegressor
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error

# %%
columns = ['date_time', 'hour_assignment', 'perceived_temperature', 'discomfort_index']

# %%
def data_load(columns, train, test):
    train=pd.read_csv('edit_train.csv')
    test=pd.read_csv('edit_test.csv')
    submission=pd.read_csv('energy/sample_submission.csv', encoding='cp949')
    
    train = train.drop(columns, axis=1)
    test = test.drop(columns, axis=1)

    features = train.drop('전력사용량(kWh)', axis=1)
    labels = train[['전력사용량(kWh)']]
    
    return train, test, features, labels

# %%
def Kfold(train, N=None):
    kfold = KFold(n_splits=N, shuffle=True, random_state=0)
    fold = 1
    models = {}

    for train_idx, valid_idx in kfold.split(train):
        print('\n ================== Fold {} =================='.format(fold))

        X_train, X_valid = features.iloc[train_idx, :], features.iloc[valid_idx, :]
        y_train, y_valid = labels.iloc[train_idx, :], labels.iloc[valid_idx, :]

        model = LGBMRegressor(n_estimators=10000, random_state=0)
        model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_valid, y_valid)], early_stopping_rounds=30, verbose=100)
        models[fold] = model

        fold += 1
    
    return models

# %%
train, test, features, labels = data_load(columns, train, test)
models = Kfold(train, 5)
# Out:
#  ================== Fold 1 ==================
# Training until validation scores don't improve for 30 rounds
# [100]	training's l2: 88063.2	valid_1's l2: 96292.9
# [200]	training's l2: 64388.6	valid_1's l2: 75092.9
# [300]	training's l2: 52802.5	valid_1's l2: 65223.9
# [400]	training's l2: 46369.3	valid_1's l2: 60144
# [500]	training's l2: 42075.9	valid_1's l2: 56647.8
# [600]	training's l2: 38535.9	valid_1's l2: 54372.6
# [700]	training's l2: 35708.1	valid_1's l2: 52649.5
# [800]	training's l2: 33618.3	valid_1's l2: 51377.7
# [900]	training's l2: 31993.4	valid_1's l2: 50560.5
# [1000]	training's l2: 30488.3	valid_1's l2: 49868.7
# [1100]	training's l2: 29025	valid_1's l2: 48976.7
# [1200]	training's l2: 27757.1	valid_1's l2: 48406.9
# [1300]	training's l2: 26665.2	valid_1's l2: 47911.9
# [1400]	training's l2: 25423.8	valid_1's l2: 47282.2
# [1500]	training's l2: 24520.2	valid_1's l2: 46901.7
# [1600]	training's l2: 23691.2	valid_1's l2: 46617.2
# [1700]	training's l2: 22728.7	valid_1's l2: 46163.2
# [1800]	training's l2: 21965.1	valid_1's l2: 45832.6
# [1900]	training's l2: 21134.6	valid_1's l2: 45549.1
# [2000]	training's l2: 20524.5	valid_1's l2: 45369.8
# [2100]	training's l2: 19906.2	valid_1's l2: 45133.6
# Early stopping, best iteration is:
# [2131]	training's l2: 19774.2	valid_1's l2: 45090.5
#
#  ================== Fold 2 ==================
# Training until validation scores don't improve for 30 rounds
# [100]	training's l2: 87716.2	valid_1's l2: 86856.9
# [200]	training's l2: 64123.6	valid_1's l2: 66300.2
# [300]	training's l2: 54043.9	valid_1's l2: 57755
# [400]	training's l2: 47851	valid_1's l2: 53373.3
# [500]	training's l2: 43563.1	valid_1's l2: 50848.1
# [600]	training's l2: 40016	valid_1's l2: 48778.3
# [700]	training's l2: 37287.8	valid_1's l2: 47085.2
# [800]	training's l2: 34435.1	valid_1's l2: 45610.6
# [900]	training's l2: 32737.1	valid_1's l2: 44791.8
# [1000]	training's l2: 31284.6	valid_1's l2: 44147.7
# [1100]	training's l2: 29738.8	valid_1's l2: 43366.2
# [1200]	training's l2: 28278.9	valid_1's l2: 42856.6
# [1300]	training's l2: 26857.5	valid_1's l2: 42105.8
# [1400]	training's l2: 25667.1	valid_1's l2: 41602.6
# [1500]	training's l2: 24520.1	valid_1's l2: 41085.6
# [1600]	training's l2: 23694.8	valid_1's l2: 40690.8
# [1700]	training's l2: 22880.1	valid_1's l2: 40416
# [1800]	training's l2: 22107.6	valid_1's l2: 40227
# [1900]	training's l2: 21553.5	valid_1's l2: 40037.5
# [2000]	training's l2: 20925.9	valid_1's l2: 39800.2
# [2100]	training's l2: 20349.1	valid_1's l2: 39633
# [2200]	training's l2: 19808.3	valid_1's l2: 39481.8
# Early stopping, best iteration is:
# [2251]	training's l2: 19505.2	valid_1's l2: 39378.2
#
#  ================== Fold 3 ==================
# Training until validation scores don't improve for 30 rounds
# [100]	training's l2: 86983.3	valid_1's l2: 88156.1
# [200]	training's l2: 65154.4	valid_1's l2: 68664.1
# [300]	training's l2: 54868	valid_1's l2: 60349.9
# [400]	training's l2: 48261.1	valid_1's l2: 55213.2
# [500]	training's l2: 43711.2	valid_1's l2: 52105.1
# [600]	training's l2: 40260.9	valid_1's l2: 50156.6
# [700]	training's l2: 37100.7	valid_1's l2: 48403.4
# [800]	training's l2: 34834.7	valid_1's l2: 47148.6
# [900]	training's l2: 32922.8	valid_1's l2: 46198.2
# [1000]	training's l2: 31340.8	valid_1's l2: 45389.4
# [1100]	training's l2: 29825.4	valid_1's l2: 44738.1
# [1200]	training's l2: 28288.8	valid_1's l2: 43981.5
# [1300]	training's l2: 27121.2	valid_1's l2: 43420.8
# [1400]	training's l2: 26117.6	valid_1's l2: 43018.1
# [1500]	training's l2: 25063.6	valid_1's l2: 42569.7
# [1600]	training's l2: 23896.8	valid_1's l2: 42029.5
# [1700]	training's l2: 22941.2	valid_1's l2: 41753.6
# [1800]	training's l2: 22100.7	valid_1's l2: 41404.9
# [1900]	training's l2: 21438.2	valid_1's l2: 41131.3
# [2000]	training's l2: 20773.9	valid_1's l2: 40881.5
# Early stopping, best iteration is:
# [2056]	training's l2: 20460.6	valid_1's l2: 40742.2
#
#  ================== Fold 4 ==================
# Training until validation scores don't improve for 30 rounds
# [100]	training's l2: 86475.2	valid_1's l2: 89622.5
# [200]	training's l2: 64578.8	valid_1's l2: 70860.1
# [300]	training's l2: 53069.1	valid_1's l2: 62124.9
# [400]	training's l2: 46958.3	valid_1's l2: 57725.8
# [500]	training's l2: 42457.1	valid_1's l2: 54589.6
# [600]	training's l2: 39141.1	valid_1's l2: 52666.9
# [700]	training's l2: 36590.4	valid_1's l2: 51225.5
# [800]	training's l2: 34455	valid_1's l2: 50174.4
# [900]	training's l2: 32447.1	valid_1's l2: 49260.4
# [1000]	training's l2: 30822.3	valid_1's l2: 48304.1
# [1100]	training's l2: 29011.9	valid_1's l2: 46962.2
# [1200]	training's l2: 27637	valid_1's l2: 46261.7
# [1300]	training's l2: 26327.1	valid_1's l2: 45519.5
# [1400]	training's l2: 25083.4	valid_1's l2: 44826.7
# [1500]	training's l2: 24118.1	valid_1's l2: 44378.7
# [1600]	training's l2: 23341	valid_1's l2: 44047.6
# [1700]	training's l2: 22671.8	valid_1's l2: 43808.1
# [1800]	training's l2: 21983.9	valid_1's l2: 43517.7
# [1900]	training's l2: 21321.8	valid_1's l2: 43315.9
# Early stopping, best iteration is:
# [1944]	training's l2: 21007.5	valid_1's l2: 43217.6
#
#  ================== Fold 5 ==================
# Training until validation scores don't improve for 30 rounds
# [100]	training's l2: 86340.8	valid_1's l2: 96248.6
# [200]	training's l2: 63362.5	valid_1's l2: 74947.3
# [300]	training's l2: 51932.2	valid_1's l2: 65271.4
# [400]	training's l2: 45539.7	valid_1's l2: 60335.7
# [500]	training's l2: 41660.4	valid_1's l2: 57531.9
# [600]	training's l2: 38292.5	valid_1's l2: 55284.8
# [700]	training's l2: 35716.6	valid_1's l2: 53701
# [800]	training's l2: 33599.3	valid_1's l2: 52187.2
# [900]	training's l2: 31617	valid_1's l2: 50975.7
# [1000]	training's l2: 30234.9	valid_1's l2: 50191
# [1100]	training's l2: 28618.2	valid_1's l2: 49301.1
# [1200]	training's l2: 27221.7	valid_1's l2: 48548.3
# [1300]	training's l2: 26160.4	valid_1's l2: 48048.6
# [1400]	training's l2: 25249.4	valid_1's l2: 47658.4
# [1500]	training's l2: 24258	valid_1's l2: 47030
# [1600]	training's l2: 23229.7	valid_1's l2: 46527.7
# [1700]	training's l2: 22518.6	valid_1's l2: 46366
# [1800]	training's l2: 21732.1	valid_1's l2: 45949
# [1900]	training's l2: 21023.9	valid_1's l2: 45621
# [2000]	training's l2: 20396.3	valid_1's l2: 45339.4
# [2100]	training's l2: 19845	valid_1's l2: 45092.1
# [2200]	training's l2: 19275.7	valid_1's l2: 44880.6
# [2300]	training's l2: 18761.3	valid_1's l2: 44709.3
# [2400]	training's l2: 18275.4	valid_1's l2: 44472.3
# [2500]	training's l2: 17852.2	valid_1's l2: 44333.7
# Early stopping, best iteration is:
# [2509]	training's l2: 17821.1	valid_1's l2: 44323.3

# %%
submission = pd.read_csv('energy/sample_submission.csv', encoding='cp949')

for i in range(1, 6):
    submission['answer'] += models[i].predict(test)/5

submission.to_csv('lgbm_day2_1.csv', index=False)

# %%
columns = ['date_time', 'perceived_temperature', 'discomfort_index']

# %%
train, test, features, labels = data_load(columns, train, test)
models = Kfold(train, 5)
# Out:
#  ================== Fold 1 ==================
# Training until validation scores don't improve for 30 rounds
# [100]	training's l2: 88822.1	valid_1's l2: 97096.3
# [200]	training's l2: 64636.4	valid_1's l2: 75471.5
# [300]	training's l2: 52643.6	valid_1's l2: 65707.8
# [400]	training's l2: 45842.4	valid_1's l2: 60218.7
# [500]	training's l2: 41486.4	valid_1's l2: 56735.5
# [600]	training's l2: 38349.4	valid_1's l2: 54538.8
# [700]	training's l2: 35775.4	valid_1's l2: 53040.7
# [800]	training's l2: 33490.6	valid_1's l2: 51714
# [900]	training's l2: 31833.9	valid_1's l2: 50726.7
# [1000]	training's l2: 30167	valid_1's l2: 49968.3
# [1100]	training's l2: 28867.7	valid_1's l2: 49499.4
# [1200]	training's l2: 27645.8	valid_1's l2: 48904.8
# [1300]	training's l2: 26484.2	valid_1's l2: 48415.2
# Early stopping, best iteration is:
# [1363]	training's l2: 25831.1	valid_1's l2: 48157.9
#
#  ================== Fold 2 ==================
# Training until validation scores don't improve for 30 rounds
# [100]	training's l2: 86616.1	valid_1's l2: 85906.2
# [200]	training's l2: 62731.6	valid_1's l2: 65319.6
# [300]	training's l2: 52380.2	valid_1's l2: 57228.4
# [400]	training's l2: 46534.4	valid_1's l2: 52726.4
# [500]	training's l2: 42499.5	valid_1's l2: 50513.9
# [600]	training's l2: 38960.4	valid_1's l2: 48267.6
# [700]	training's l2: 36341.4	valid_1's l2: 46926.1
# [800]	training's l2: 34297.2	valid_1's l2: 45899.7
# [900]	training's l2: 32409.6	valid_1's l2: 44933.3
# [1000]	training's l2: 30962.7	valid_1's l2: 44227.2
# [1100]	training's l2: 29553.4	valid_1's l2: 43715.7
# [1200]	training's l2: 28040.1	valid_1's l2: 42955.7
# [1300]	training's l2: 26914.9	valid_1's l2: 42521.2
# [1400]	training's l2: 25938.4	valid_1's l2: 42195.6
# [1500]	training's l2: 24924.8	valid_1's l2: 41851.5
# [1600]	training's l2: 24094.6	valid_1's l2: 41499.8
# [1700]	training's l2: 23236.8	valid_1's l2: 41058.2
# [1800]	training's l2: 22314.8	valid_1's l2: 40725.2
# [1900]	training's l2: 21494.4	valid_1's l2: 40377.6
# [2000]	training's l2: 20841.5	valid_1's l2: 40216.4
# [2100]	training's l2: 20168.1	valid_1's l2: 40039.3
# [2200]	training's l2: 19577.3	valid_1's l2: 39842.4
# [2300]	training's l2: 19072.9	valid_1's l2: 39721.7
# [2400]	training's l2: 18467.5	valid_1's l2: 39577.8
# [2500]	training's l2: 17970	valid_1's l2: 39439.9
# Early stopping, best iteration is:
# [2527]	training's l2: 17799.8	valid_1's l2: 39349.6
#
#  ================== Fold 3 ==================
# Training until validation scores don't improve for 30 rounds
# [100]	training's l2: 87596.5	valid_1's l2: 89191.9
# [200]	training's l2: 65778.2	valid_1's l2: 70438.4
# [300]	training's l2: 54414.7	valid_1's l2: 60798.6
# [400]	training's l2: 47850	valid_1's l2: 55660.7
# [500]	training's l2: 43358.9	valid_1's l2: 52753.4
# [600]	training's l2: 39459.5	valid_1's l2: 50507.3
# [700]	training's l2: 36905.6	valid_1's l2: 49315.9
# [800]	training's l2: 35107.9	valid_1's l2: 48423.4
# [900]	training's l2: 33102.3	valid_1's l2: 47337.1
# [1000]	training's l2: 31326	valid_1's l2: 46270.5
# [1100]	training's l2: 29740.9	valid_1's l2: 45376.6
# [1200]	training's l2: 28488.3	valid_1's l2: 44751.5
# [1300]	training's l2: 27197.4	valid_1's l2: 44135
# [1400]	training's l2: 26107.1	valid_1's l2: 43674.7
# [1500]	training's l2: 25087.3	valid_1's l2: 43273.7
# [1600]	training's l2: 24076	valid_1's l2: 42900.5
# [1700]	training's l2: 23141	valid_1's l2: 42450.2
# [1800]	training's l2: 22474.1	valid_1's l2: 42257.1
# [1900]	training's l2: 21812.5	valid_1's l2: 41957.9
# [2000]	training's l2: 21076.8	valid_1's l2: 41664.6
# [2100]	training's l2: 20381.2	valid_1's l2: 41224.8
# [2200]	training's l2: 19891.3	valid_1's l2: 41081.1
# [2300]	training's l2: 19367.6	valid_1's l2: 40898.7
# [2400]	training's l2: 18798	valid_1's l2: 40650.1
# [2500]	training's l2: 18276.1	valid_1's l2: 40532
# [2600]	training's l2: 17756	valid_1's l2: 40378.3
# [2700]	training's l2: 17341.8	valid_1's l2: 40244.7
# Early stopping, best iteration is:
# [2685]	training's l2: 17401.1	valid_1's l2: 40233.4
#
#  ================== Fold 4 ==================
# Training until validation scores don't improve for 30 rounds
# [100]	training's l2: 85260.1	valid_1's l2: 89492.4
# [200]	training's l2: 63883.6	valid_1's l2: 70752.3
# [300]	training's l2: 53033.2	valid_1's l2: 62102.9
# [400]	training's l2: 47175.2	valid_1's l2: 58132.1
# [500]	training's l2: 42696.9	valid_1's l2: 55282.6
# [600]	training's l2: 39210.6	valid_1's l2: 52910.4
# [700]	training's l2: 36431.3	valid_1's l2: 51105.5
# [800]	training's l2: 34239.6	valid_1's l2: 49698
# [900]	training's l2: 32083	valid_1's l2: 48609.9
# [1000]	training's l2: 30663.5	valid_1's l2: 47812.4
# [1100]	training's l2: 28957.5	valid_1's l2: 46854.8
# [1200]	training's l2: 27719.4	valid_1's l2: 46165.9
# [1300]	training's l2: 26467.2	valid_1's l2: 45228.9
# [1400]	training's l2: 25446.5	valid_1's l2: 44648.6
# [1500]	training's l2: 24551.5	valid_1's l2: 44337.4
# [1600]	training's l2: 23587	valid_1's l2: 43932.2
# [1700]	training's l2: 22839.5	valid_1's l2: 43650
# [1800]	training's l2: 22062	valid_1's l2: 43369.2
# [1900]	training's l2: 21216.9	valid_1's l2: 43033.4
# [2000]	training's l2: 20467.2	valid_1's l2: 42821.5
# [2100]	training's l2: 19895.9	valid_1's l2: 42638.1
# [2200]	training's l2: 19368.3	valid_1's l2: 42451.9
# [2300]	training's l2: 18784.8	valid_1's l2: 42224
# [2400]	training's l2: 18336.4	valid_1's l2: 42048.6
# [2500]	training's l2: 17810.7	valid_1's l2: 41915.8
# [2600]	training's l2: 17369.6	valid_1's l2: 41718.1
# [2700]	training's l2: 16935.5	valid_1's l2: 41624.4
# [2800]	training's l2: 16499.9	valid_1's l2: 41498.9
# [2900]	training's l2: 16077.7	valid_1's l2: 41408
# [3000]	training's l2: 15744.1	valid_1's l2: 41340.2
# [3100]	training's l2: 15413	valid_1's l2: 41277.9
# [3200]	training's l2: 15079.3	valid_1's l2: 41128.3
# [3300]	training's l2: 14765.6	valid_1's l2: 41036.1
# [3400]	training's l2: 14438.4	valid_1's l2: 40938.3
# [3500]	training's l2: 14097.7	valid_1's l2: 40789.7
# [3600]	training's l2: 13777.1	valid_1's l2: 40670.2
# [3700]	training's l2: 13476.5	valid_1's l2: 40587.4
# [3800]	training's l2: 13143.9	valid_1's l2: 40523.7
# [3900]	training's l2: 12833.7	valid_1's l2: 40439.6
# [4000]	training's l2: 12579.7	valid_1's l2: 40373.2
# Early stopping, best iteration is:
# [3985]	training's l2: 12619.2	valid_1's l2: 40371.5
#
#  ================== Fold 5 ==================
# Training until validation scores don't improve for 30 rounds
# [100]	training's l2: 86604.2	valid_1's l2: 96273.7
# [200]	training's l2: 61905.2	valid_1's l2: 73337.3
# [300]	training's l2: 52736.9	valid_1's l2: 66018.6
# [400]	training's l2: 46243	valid_1's l2: 60610.8
# [500]	training's l2: 41802.3	valid_1's l2: 57371.1
# [600]	training's l2: 38336	valid_1's l2: 55215.1
# [700]	training's l2: 35640.7	valid_1's l2: 53461.1
# [800]	training's l2: 33559	valid_1's l2: 52204.5
# [900]	training's l2: 31801.2	valid_1's l2: 51225.6
# [1000]	training's l2: 30365.5	valid_1's l2: 50513
# [1100]	training's l2: 28879.8	valid_1's l2: 49876.3
# [1200]	training's l2: 27420.5	valid_1's l2: 49093.5
# [1300]	training's l2: 26155.1	valid_1's l2: 48353.1
# [1400]	training's l2: 25090.1	valid_1's l2: 47782.7
# [1500]	training's l2: 24239.4	valid_1's l2: 47443.4
# [1600]	training's l2: 23379.6	valid_1's l2: 47116.1
# [1700]	training's l2: 22618.9	valid_1's l2: 46881.9
# Early stopping, best iteration is:
# [1768]	training's l2: 22052	valid_1's l2: 46632.9

# %%
submission = pd.read_csv('energy/sample_submission.csv', encoding='cp949')

for i in range(1, 6):
    submission['answer'] += models[i].predict(test)/5

submission.to_csv('lgbm_day2_2.csv', index=False)

# %%
columns = ['date_time']

# %%
train, test, features, labels = data_load(columns, train, test)
models = Kfold(train, 5)
# Out:
#  ================== Fold 1 ==================
# Training until validation scores don't improve for 30 rounds
# [100]	training's l2: 84066.2	valid_1's l2: 92596.6
# [200]	training's l2: 60504.3	valid_1's l2: 71512.6
# [300]	training's l2: 50717	valid_1's l2: 63494.5
# [400]	training's l2: 44724	valid_1's l2: 58769.2
# [500]	training's l2: 40340	valid_1's l2: 55600
# [600]	training's l2: 37203.9	valid_1's l2: 53443.7
# [700]	training's l2: 34808.7	valid_1's l2: 51818.3
# [800]	training's l2: 32557.8	valid_1's l2: 50506.6
# [900]	training's l2: 30992.7	valid_1's l2: 49691
# [1000]	training's l2: 29349.4	valid_1's l2: 48995.8
# [1100]	training's l2: 27619.3	valid_1's l2: 48219.6
# [1200]	training's l2: 26357.2	valid_1's l2: 47713.3
# [1300]	training's l2: 25150.2	valid_1's l2: 47080.5
# [1400]	training's l2: 24216.4	valid_1's l2: 46702.9
# [1500]	training's l2: 23241.5	valid_1's l2: 46236.1
# Early stopping, best iteration is:
# [1536]	training's l2: 22963.1	valid_1's l2: 46109.6
#
#  ================== Fold 2 ==================
# Training until validation scores don't improve for 30 rounds
# [100]	training's l2: 84763.9	valid_1's l2: 83583.5
# [200]	training's l2: 61438.9	valid_1's l2: 63261.9
# [300]	training's l2: 50852.3	valid_1's l2: 55349.8
# [400]	training's l2: 45074.4	valid_1's l2: 51554.9
# [500]	training's l2: 41018.8	valid_1's l2: 49029.8
# [600]	training's l2: 37503.1	valid_1's l2: 46891.7
# [700]	training's l2: 35121.3	valid_1's l2: 45521.3
# [800]	training's l2: 33045.6	valid_1's l2: 44420.6
# [900]	training's l2: 30971.4	valid_1's l2: 43517.1
# [1000]	training's l2: 29317.7	valid_1's l2: 42692.4
# [1100]	training's l2: 27719.6	valid_1's l2: 41880
# [1200]	training's l2: 26212.8	valid_1's l2: 41252.2
# [1300]	training's l2: 25211.1	valid_1's l2: 40850
# [1400]	training's l2: 24371.3	valid_1's l2: 40505.3
# [1500]	training's l2: 23537.8	valid_1's l2: 40259
# [1600]	training's l2: 22712	valid_1's l2: 39967.3
# [1700]	training's l2: 21999.8	valid_1's l2: 39791.2
# [1800]	training's l2: 21175	valid_1's l2: 39511
# [1900]	training's l2: 20436.9	valid_1's l2: 39267.6
# [2000]	training's l2: 19710.6	valid_1's l2: 39057.8
# [2100]	training's l2: 19034.1	valid_1's l2: 38801.3
# [2200]	training's l2: 18408	valid_1's l2: 38653.3
# [2300]	training's l2: 17884.2	valid_1's l2: 38491.9
# [2400]	training's l2: 17331.8	valid_1's l2: 38434
# [2500]	training's l2: 16827.6	valid_1's l2: 38259.8
# Early stopping, best iteration is:
# [2503]	training's l2: 16814.8	valid_1's l2: 38258.5
#
#  ================== Fold 3 ==================
# Training until validation scores don't improve for 30 rounds
# [100]	training's l2: 85727.7	valid_1's l2: 88191.5
# [200]	training's l2: 63457.4	valid_1's l2: 69531
# [300]	training's l2: 51967.9	valid_1's l2: 59775.1
# [400]	training's l2: 44726.2	valid_1's l2: 54096
# [500]	training's l2: 40685.4	valid_1's l2: 51313.6
# [600]	training's l2: 37530	valid_1's l2: 49291.5
# [700]	training's l2: 35026.5	valid_1's l2: 47814.3
# [800]	training's l2: 32944.2	valid_1's l2: 46588.8
# [900]	training's l2: 31212.6	valid_1's l2: 45786
# [1000]	training's l2: 29561.8	valid_1's l2: 45105.7
# [1100]	training's l2: 28229.7	valid_1's l2: 44634.7
# [1200]	training's l2: 27145.8	valid_1's l2: 44188.7
# [1300]	training's l2: 25996.4	valid_1's l2: 43835
# [1400]	training's l2: 24986	valid_1's l2: 43420.1
# [1500]	training's l2: 23975.5	valid_1's l2: 42947.6
# [1600]	training's l2: 23169.2	valid_1's l2: 42548.7
# [1700]	training's l2: 22248	valid_1's l2: 42261.7
# [1800]	training's l2: 21404.3	valid_1's l2: 41965.5
# [1900]	training's l2: 20699.4	valid_1's l2: 41673.1
# [2000]	training's l2: 19969.7	valid_1's l2: 41390.3
# [2100]	training's l2: 19466.4	valid_1's l2: 41255.8
# [2200]	training's l2: 18850.8	valid_1's l2: 41039.7
# [2300]	training's l2: 18331.4	valid_1's l2: 40829.8
# [2400]	training's l2: 17818.4	valid_1's l2: 40706.1
# [2500]	training's l2: 17319.2	valid_1's l2: 40537.6
# [2600]	training's l2: 16779.8	valid_1's l2: 40397.8
# [2700]	training's l2: 16326.2	valid_1's l2: 40228.7
# [2800]	training's l2: 15822.1	valid_1's l2: 40143
# [2900]	training's l2: 15287.7	valid_1's l2: 40018.8
# [3000]	training's l2: 14845.6	valid_1's l2: 39841.8
# [3100]	training's l2: 14468.5	valid_1's l2: 39716.7
# [3200]	training's l2: 14083.2	valid_1's l2: 39627
# Early stopping, best iteration is:
# [3213]	training's l2: 14036	valid_1's l2: 39615.3
#
#  ================== Fold 4 ==================
# Training until validation scores don't improve for 30 rounds
# [100]	training's l2: 84761.9	valid_1's l2: 89043.1
# [200]	training's l2: 62453.2	valid_1's l2: 69445
# [300]	training's l2: 51427.8	valid_1's l2: 60596.7
# [400]	training's l2: 45014.7	valid_1's l2: 55852.3
# [500]	training's l2: 41022.3	valid_1's l2: 53096.2
# [600]	training's l2: 37314.2	valid_1's l2: 50728.5
# [700]	training's l2: 34904.3	valid_1's l2: 49691.9
# [800]	training's l2: 32655.9	valid_1's l2: 48501.5
# [900]	training's l2: 30849.5	valid_1's l2: 47510.3
# [1000]	training's l2: 29258.7	valid_1's l2: 46712.3
# [1100]	training's l2: 27955.9	valid_1's l2: 46069.2
# [1200]	training's l2: 26630.3	valid_1's l2: 45534.2
# [1300]	training's l2: 25534.5	valid_1's l2: 45115.9
# [1400]	training's l2: 24496.6	valid_1's l2: 44521.3
# [1500]	training's l2: 23682.6	valid_1's l2: 44207.7
# [1600]	training's l2: 22650.9	valid_1's l2: 43666.7
# [1700]	training's l2: 21746.3	valid_1's l2: 43224.2
# [1800]	training's l2: 21018.9	valid_1's l2: 42949.3
# [1900]	training's l2: 20412.2	valid_1's l2: 42755.9
# [2000]	training's l2: 19824.7	valid_1's l2: 42551.4
# [2100]	training's l2: 19209.6	valid_1's l2: 42352.3
# [2200]	training's l2: 18660.9	valid_1's l2: 42209
# [2300]	training's l2: 18092.7	valid_1's l2: 42082.9
# [2400]	training's l2: 17529	valid_1's l2: 41921.2
# Early stopping, best iteration is:
# [2370]	training's l2: 17654.6	valid_1's l2: 41920.5
#
#  ================== Fold 5 ==================
# Training until validation scores don't improve for 30 rounds
# [100]	training's l2: 83073	valid_1's l2: 91619.2
# [200]	training's l2: 61389.1	valid_1's l2: 71758.3
# [300]	training's l2: 50143.1	valid_1's l2: 62465.5
# [400]	training's l2: 44433.3	valid_1's l2: 58149.4
# [500]	training's l2: 40229.5	valid_1's l2: 55611.8
# [600]	training's l2: 37247.3	valid_1's l2: 53789.2
# [700]	training's l2: 34662.4	valid_1's l2: 52259.5
# [800]	training's l2: 32543.5	valid_1's l2: 50876.7
# [900]	training's l2: 30775.6	valid_1's l2: 50043
# [1000]	training's l2: 28950.6	valid_1's l2: 48993.1
# [1100]	training's l2: 27486.1	valid_1's l2: 48251
# [1200]	training's l2: 26290.2	valid_1's l2: 47670.2
# [1300]	training's l2: 25225.8	valid_1's l2: 47338.3
# Early stopping, best iteration is:
# [1274]	training's l2: 25511.2	valid_1's l2: 47322.3

# %%
submission = pd.read_csv('energy/sample_submission.csv', encoding='cp949')

for i in range(1, 6):
    submission['answer'] += models[i].predict(test)/5

submission.to_csv('lgbm_day2_3.csv', index=False)
