# %%
import math
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.decomposition import PCA

# %%
train = pd.read_csv('edit_train.csv')
test = pd.read_csv('edit_test.csv')
cluster_df = train.iloc[:, :3].drop('date_time', axis=1)

# %%
def cluster_evaluate(cluster_df, n_cluster, dic):

    scaler = StandardScaler()
    result = scaler.fit_transform(cluster_df)
    data_scaled = pd.DataFrame(result)
    
    pca = PCA(n_components=2)
    result = pca.fit_transform(data_scaled)
    df = pd.DataFrame(result, columns=["x", "y"])
    
    scaler = StandardScaler()
    result = scaler.fit_transform(df)
#     df = pd.DataFrame(result, columns=["x", "y"])
    
    markers = ['o', 's', '^', 'P']
    fig, axs = plt.subplots(figsize=(15,4), ncols=4)

    for ax, i in enumerate(n_cluster):
        df = pd.DataFrame(result, columns=["x", "y"])
        
        kmeans = KMeans(n_clusters=i, random_state=0)
        kmeans.fit(result)
        pred_cluster = kmeans.predict(result)
        df['cluster_label'] = pred_cluster

        score_samples = silhouette_samples(result, df['cluster_label'])
        df['silhouette_coeff'] = score_samples

        mean_score = silhouette_score(result, df['cluster_label'])

        print('===== n_cluster:{0} ====='.format(i))
        print(df.groupby('cluster_label')['silhouette_coeff'].mean())
        print('mean_score:{0:.4f}'.format(mean_score), '\n')
        
        cluster_unique = df['cluster_label'].unique()
        axs[ax].set_title('n_cluster:{0}'.format(i))
        
        for j in cluster_unique:
            cluster_target = df[df['cluster_label'] == j]
            axs[ax].scatter(cluster_target['x'], cluster_target['y'],
                            marker=markers[ax])
        
        dic['kmeans'+str(i)] = df
        
    plt.show()
    
    return dic

# %%
def gmm_cluster_evaluate(cluster_df, n_cluster, dic):

    scaler = StandardScaler()
    result = scaler.fit_transform(cluster_df)
    data_scaled = pd.DataFrame(result)
    
    pca = PCA(n_components=2)
    result = pca.fit_transform(data_scaled)
    df = pd.DataFrame(result, columns=["x", "y"])
    
    scaler = StandardScaler()
    result = scaler.fit_transform(df)
#     df = pd.DataFrame(result, columns=["x", "y"])
    
    markers = ['o', 's', '^', 'P']
    fig, axs = plt.subplots(figsize=(15,4), ncols=4)
    
    for ax, i in enumerate(n_cluster):
        df = pd.DataFrame(result, columns=["x", "y"])
        
        gmm = GaussianMixture(n_components=i, random_state=0)
        gmm.fit(result)
        pred_cluster = gmm.predict(result)
        df['cluster_label'] = pred_cluster

        score_samples = silhouette_samples(result, df['cluster_label'])
        df['silhouette_coeff'] = score_samples

        mean_score = silhouette_score(result, df['cluster_label'])

        print('===== n_cluster:{0} ====='.format(i))
        print(df.groupby('cluster_label')['silhouette_coeff'].mean())
        print('mean_score:{0:.4f}'.format(mean_score), '\n')

        cluster_unique = df['cluster_label'].unique()
        axs[ax].set_title('n_cluster:{0}'.format(i))
        
        for j in cluster_unique:
            cluster_target = df[df['cluster_label'] == j]
            axs[ax].scatter(cluster_target['x'], cluster_target['y'],
                            marker=markers[ax])
        
        dic['gmm'+str(i)] = df
        
    plt.show()
    
    return dic

# %%
hour_cluster = pd.DataFrame(np.array(train.groupby(['date_time']).mean().iloc[:,1]).reshape(-1, 24).T)
num_cluster = pd.DataFrame(np.array(cluster_df.iloc[:, 1]).reshape(-1, 2040), index=range(1, 61))

knn_n_cluster = [4, 5]
gmm_n_cluster = [4, 5]

# %%
hour_dic = {}
hour_dic = cluster_evaluate(hour_cluster, knn_n_cluster, hour_dic)
hour_dic = gmm_cluster_evaluate(hour_cluster, gmm_n_cluster, hour_dic)
# Out:
# ===== n_cluster:4 =====
# cluster_label
# 0    0.605761
# 1    0.668038
# 2    0.498874
# 3    0.759125
# Name: silhouette_coeff, dtype: float64
# mean_score:0.6323
#
# ===== n_cluster:5 =====
# cluster_label
# 0    0.668038
# 1    0.587653
# 2    0.446724
# 3    0.542572
# 4    0.706631
# Name: silhouette_coeff, dtype: float64
# mean_score:0.6004
# ===== n_cluster:4 =====
# cluster_label
# 0    0.668701
# 1    0.661231
# 2    0.434864
# 3    0.486354
# Name: silhouette_coeff, dtype: float64
# mean_score:0.6041
#
# ===== n_cluster:5 =====
# cluster_label
# 0    0.668038
# 1    0.658103
# 2    0.743418
# 3    0.379959
# 4    0.231305
# Name: silhouette_coeff, dtype: float64
# mean_score:0.5128

# %%
num_dic = {}

num_dic = cluster_evaluate(num_cluster, knn_n_cluster, num_dic)
num_dic = gmm_cluster_evaluate(num_cluster, gmm_n_cluster, num_dic)
# Out:
# ===== n_cluster:4 =====
# cluster_label
# 0    0.431094
# 1    0.765815
# 2    0.326862
# 3    0.392485
# Name: silhouette_coeff, dtype: float64
# mean_score:0.4263
#
# ===== n_cluster:5 =====
# cluster_label
# 0    0.549248
# 1    0.759538
# 2    0.160563
# 3    0.351369
# 4    0.304812
# Name: silhouette_coeff, dtype: float64
# mean_score:0.4460
# ===== n_cluster:4 =====
# cluster_label
# 0    0.412509
# 1    0.769988
# 2   -0.020176
# 3    0.375368
# Name: silhouette_coeff, dtype: float64
# mean_score:0.3647
#
# ===== n_cluster:5 =====
# cluster_label
# 0    0.567265
# 1    0.768680
# 2    0.164590
# 3    0.329649
# 4    0.206325
# Name: silhouette_coeff, dtype: float64
# mean_score:0.4235

# %%
plt.figure(figsize=(15, 6))
for i in hour_cluster.index:
    sns.distplot(hour_cluster.iloc[i, :], hist=False)
plt.show()

# %%
c = hour_df['cluster_label']
hour_cluster['cluster'] = c
hour_group_cluster = hour_cluster.groupby('cluster').mean()

plt.figure(figsize=(15, 6))
for i in hour_group_cluster.index:
    sns.distplot(hour_group_cluster.loc[i, :], hist=False)
plt.show()

# %%
c = hour_df['cluster_label']
hour_cluster['cluster'] = c
hour_group_cluster = hour_cluster.groupby('cluster').mean()

plt.figure(figsize=(15, 6))
for i in hour_group_cluster.index:
    sns.distplot(hour_group_cluster.loc[i, :], hist=False)
plt.show()

# %%
plt.figure(figsize=(15, 6))
for i in num_cluster.index:
    sns.distplot(num_cluster.loc[i, :], hist=False)
plt.show()

# %%
c = gmm_num_df['cluster_label']
num_cluster['cluster'] = c
num_group_cluster = num_cluster.groupby('cluster').mean()

plt.figure(figsize=(15, 6))
for i in num_group_cluster.index:
    sns.distplot(num_group_cluster.loc[i, :], hist=False)
plt.show()

# %%
hour_df = cluster_evaluate(hour_cluster, n_cluster)
# gmm_hour_df = gmm_cluster_evaluate(hour_cluster, n_cluster)
# num_df = cluster_evaluate(num_cluster, n_cluster)
gmm_num_df = gmm_cluster_evaluate(num_cluster, n_cluster)
# Out:
# ===== n_cluster:3 =====
# cluster_label
# 0    0.502818
# 1    0.578223
# 2    0.779739
# Name: silhouette_coeff, dtype: float64
# mean_score:0.5720
#
# ===== n_cluster:4 =====
# cluster_label
# 0    0.605761
# 1    0.668038
# 2    0.498874
# 3    0.759125
# Name: silhouette_coeff, dtype: float64
# mean_score:0.6323
#
# ===== n_cluster:5 =====
# cluster_label
# 0    0.668038
# 1    0.587653
# 2    0.446724
# 3    0.542572
# 4    0.706631
# Name: silhouette_coeff, dtype: float64
# mean_score:0.6004
#
# ===== n_cluster:6 =====
# cluster_label
# 0    0.438132
# 1    0.587653
# 2    0.393841
# 3    0.542572
# 4    0.695789
# 5    0.355389
# Name: silhouette_coeff, dtype: float64
# mean_score:0.5020
# ===== n_cluster:3 =====
# cluster_label
# 0    0.581765
# 1    0.384741
# 2    0.189352
# Name: silhouette_coeff, dtype: float64
# mean_score:0.3772
#
# ===== n_cluster:4 =====
# cluster_label
# 0    0.668701
# 1    0.661231
# 2    0.434864
# 3    0.486354
# Name: silhouette_coeff, dtype: float64
# mean_score:0.6041
#
# ===== n_cluster:5 =====
# cluster_label
# 0    0.668038
# 1    0.658103
# 2    0.743418
# 3    0.379959
# 4    0.231305
# Name: silhouette_coeff, dtype: float64
# mean_score:0.5128
#
# ===== n_cluster:6 =====
# cluster_label
# 0    0.419589
# 1    0.658103
# 2    0.711236
# 3    0.352820
# 4    0.231305
# 5    0.374505
# Name: silhouette_coeff, dtype: float64
# mean_score:0.4170
# ===== n_cluster:3 =====
# cluster_label
# 0    0.681545
# 1    0.246640
# 2    0.791912
# Name: silhouette_coeff, dtype: float64
# mean_score:0.6490
#
# ===== n_cluster:4 =====
# cluster_label
# 0    0.431094
# 1    0.765815
# 2    0.326862
# 3    0.392485
# Name: silhouette_coeff, dtype: float64
# mean_score:0.4263
#
# ===== n_cluster:5 =====
# cluster_label
# 0    0.549248
# 1    0.759538
# 2    0.160563
# 3    0.351369
# 4    0.304812
# Name: silhouette_coeff, dtype: float64
# mean_score:0.4460
#
# ===== n_cluster:6 =====
# cluster_label
# 0    0.304812
# 1    0.158906
# 2    0.739860
# 3    0.591076
# 4    0.549248
# 5    0.351369
# Name: silhouette_coeff, dtype: float64
# mean_score:0.4596
# ===== n_cluster:3 =====
# cluster_label
# 0    0.698778
# 1    0.792375
# 2    0.356764
# Name: silhouette_coeff, dtype: float64
# mean_score:0.6791
#
# ===== n_cluster:4 =====
# cluster_label
# 0    0.412509
# 1    0.769988
# 2   -0.020176
# 3    0.375368
# Name: silhouette_coeff, dtype: float64
# mean_score:0.3647
#
# ===== n_cluster:5 =====
# cluster_label
# 0    0.567265
# 1    0.768680
# 2    0.164590
# 3    0.329649
# 4    0.206325
# Name: silhouette_coeff, dtype: float64
# mean_score:0.4235
#
# ===== n_cluster:6 =====
# cluster_label
# 0    0.567265
# 1    0.768680
# 2    0.260631
# 3    0.329649
# 4    0.206325
# 5    0.000000
# Name: silhouette_coeff, dtype: float64
# mean_score:0.4255

# %%
#cluster=6 가장 이상적
gmm_num_df
# Out:
#            x         y  cluster_label  silhouette_coeff
# 0   3.543940 -3.179151              5          0.000000
# 1  -0.557056 -0.069206              0          0.675349
# 2   0.637145 -1.413109              4          0.387220
# 3  -0.862776  0.289739              3         -0.214707
# 4   0.274163 -1.340445              4          0.354397
# 5  -0.657919  0.675424              3          0.422775
# 6  -0.446732  0.140607              0          0.465227
# 7   3.334010  3.699873              1          0.793715
# 8  -0.547155 -0.711254              0          0.431369
# 9  -0.534552  1.176542              3          0.544842
# 10 -0.040337  2.112113              3          0.384613
# 11 -0.364107  1.372421              3          0.523843
# 12 -0.674449 -0.034387              0          0.630649
# 13 -0.307196  0.058702              0          0.532219
# 14 -0.035730 -0.873692              4          0.145173
# 15 -0.334545 -0.581698              0          0.411962
# 16 -0.728758  0.343381              3         -0.123120
# 17 -0.317988  0.516202              3          0.224079
# 18 -0.798704 -0.333560              0          0.664604
# 19 -0.445732 -0.391941              0          0.633269
# 20 -0.345134 -0.247675              0          0.642993
# 21 -0.603137 -0.204658              0          0.722552
# 22 -0.232270 -0.265035              0          0.541638
# 23  0.463568 -0.767092              4          0.441708
# 24 -0.449376  0.141482              0          0.464112
# 25  0.350412  0.126530              4          0.003446
# 26 -0.895744 -0.195831              0          0.602741
# 27 -0.024702 -0.114378              0          0.317518
# 28 -0.797201  0.055614              0          0.499182
# 29  1.869372 -0.134893              2          0.202701
# 30  2.081389 -2.033499              2          0.088050
# 31  0.092516 -1.020129              4          0.308545
# 32  0.182919 -0.937774              4          0.360105
# 33 -0.764062 -0.139732              0          0.655895
# 34 -0.603080  0.817213              3          0.515343
# 35 -0.659452 -0.244599              0          0.717444
# 36 -0.177102 -0.211038              0          0.499103
# 37  2.743863  2.922013              1          0.743645
# 38 -0.245165 -0.200641              0          0.575799
# 39  0.108531  1.120027              3          0.433045
# 40 -0.598983  0.580465              3          0.337142
# 41  0.691510  0.632426              4         -0.099443
# 42 -0.270932  0.116320              0          0.454209
# 43  0.095996 -0.202396              4         -0.171142
# 44 -0.505298 -0.225709              0          0.720660
# 45 -0.301350  0.806851              3          0.491434
# 46 -0.127972  0.574160              3          0.251886
# 47 -0.687740  0.825399              3          0.494258
# 48 -0.605407 -0.437321              0          0.648879
# 49 -0.664706 -0.399542              0          0.671455
# 50 -0.313342 -0.399728              0          0.542482
# 51  0.779523  0.125055              4          0.229451
# 52 -0.495640 -0.012725              0          0.636205
# 53  2.481751 -0.610645              2          0.491141
# 54 -0.140904  0.245597              0          0.219168
# 55 -0.890816 -0.047146              0          0.539476
# 56  0.156800 -0.388195              4          0.062193
# 57 -0.763492 -0.066496              0          0.620055
# 58 -0.671920 -0.251153              0          0.714460
# 59  0.601256 -0.787679              4          0.454241

# %%
hour_df = pd.DataFrame(train.hour.unique(), columns=['hour'])
num_df = pd.DataFrame(train.num.unique(), columns=['num'])
num_hour_df = pd.DataFrame(train.num.unique(), columns=['num'])

# %%
#feature = time, 시간별 insert

hour_cluster = pd.DataFrame(np.array(train.groupby(['date_time']).mean().iloc[:,1]).reshape(-1, 24).T)

scaler = StandardScaler()
result = scaler.fit_transform(hour_cluster)
hour_cluster = pd.DataFrame(result)

kmeans = KMeans(n_clusters=5, init='k-means++', random_state=0)
kmeans.fit(hour_cluster)
clusters = kmeans.predict(hour_cluster)

hour_df['hour_assignment'] = clusters
train = train.merge(hour_df, how='left', on='hour')
test = test.merge(hour_df, how='left', on='hour')

#feature = num, 건물별 insert

num_cluster = pd.DataFrame(np.array(cluster_df.iloc[:, 1]).reshape(-1, 2040), index=range(1, 61))

scaler = StandardScaler()
result = scaler.fit_transform(num_cluster)
num_cluster = pd.DataFrame(result)

kmeans = KMeans(n_clusters=10, init='k-means++', random_state=0)
kmeans.fit(num_cluster)
clusters = kmeans.predict(num_cluster)

num_df['num_assignment'] = clusters
train = train.merge(num_df, how='left', on='num')
test = test.merge(num_df, how='left', on='num')

# %%
hour_df = pd.DataFrame(train.hour.unique(), columns=['hour'])
num_df = pd.DataFrame(train.num.unique(), columns=['num'])
num_hour_df = pd.DataFrame(train.num.unique(), columns=['num'])

# %%
#GMM, feature = time, 시간별 insert

hour_cluster = pd.DataFrame(np.array(train.groupby(['date_time']).mean().iloc[:,1]).reshape(-1, 24).T)

gmm = GaussianMixture(n_components=5, random_state=0)
gmm.fit(hour_cluster)
clusters = gmm.predict(hour_cluster)

hour_df['gmm_hour_assignment'] = clusters
train = train.merge(hour_df, how='left', on='hour')
test = test.merge(hour_df, how='left', on='hour')

#GMM, feature = num, 건물별 insert

num_cluster = pd.DataFrame(np.array(cluster_df.iloc[:, 1]).reshape(-1, 2040), index=range(1, 61))

gmm = GaussianMixture(n_components=10, random_state=0)
gmm.fit(num_cluster)
clusters = gmm.predict(num_cluster)

num_df['gmm_num_assignment'] = clusters
train = train.merge(num_df, how='left', on='num')
test = test.merge(num_df, how='left', on='num')
