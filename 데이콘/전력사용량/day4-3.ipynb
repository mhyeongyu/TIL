# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

from lightgbm import LGBMRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor


from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
# train = pd.read_csv('edit_train.csv')
# test = pd.read_csv('edit_test.csv')
# submission = pd.read_csv('energy/sample_submission.csv', encoding='cp949')

# %%
def data_load(columns):
    train = pd.read_csv('edit_train.csv')
    test = pd.read_csv('edit_test.csv')
    submission = pd.read_csv('energy/sample_submission.csv', encoding='cp949')
    
    train = train.drop(columns, axis=1)
    test = test.drop(columns, axis=1)

    features = train.drop('전력사용량(kWh)', axis=1)
    labels = train[['전력사용량(kWh)']]
    
    return train, test, submission, features, labels

# %% [markdown]
# ## KFold

# %%
def Kfold(train, N=None):
    kfold = KFold(n_splits=N, shuffle=True, random_state=0)
    fold = 1
    models = {}

    for train_idx, valid_idx in kfold.split(train):
        print('\n ================== Fold {} =================='.format(fold))

        X_train, X_valid = features.iloc[train_idx, :], features.iloc[valid_idx, :]
        y_train, y_valid = labels.iloc[train_idx, :], labels.iloc[valid_idx, :]

        model = LGBMRegressor(n_estimators=10000, random_state=0)
        model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_valid, y_valid)], eval_metric= 'rmse', early_stopping_rounds=30, verbose=500)
        models[fold] = model
        
        pred = model.predict(X_valid)
        
        mae = mean_absolute_error(y_valid, pred)
        mse = mean_squared_error(y_valid, pred)
        rmse = np.sqrt(mean_squared_error(y_valid, pred))
        
        print('='*30)
        print('MAE: {0:.4f} \nMSE: {1:.4f} \nRMSE: {2:.4f}'.format(mae, mse, rmse))
        print('='*30)
        
        fold += 1
    
    return models

# %%
columns = ['date_time']

train, test, submission, features, labels = data_load(columns)
models = Kfold(train, 5)
# Out:
#  ================== Fold 1 ==================
# Training until validation scores don't improve for 30 rounds
# [500]	training's rmse: 161.135	training's l2: 25964.6	valid_1's rmse: 197.555	valid_1's l2: 39027.9
# [1000]	training's rmse: 133.006	training's l2: 17690.5	valid_1's rmse: 184.088	valid_1's l2: 33888.5
# [1500]	training's rmse: 115.561	training's l2: 13354.3	valid_1's rmse: 178.047	valid_1's l2: 31700.7
# [2000]	training's rmse: 103.169	training's l2: 10643.9	valid_1's rmse: 175.133	valid_1's l2: 30671.7
# [2500]	training's rmse: 93.7954	training's l2: 8797.59	valid_1's rmse: 172.959	valid_1's l2: 29914.9
# [3000]	training's rmse: 86.0275	training's l2: 7400.73	valid_1's rmse: 171.583	valid_1's l2: 29440.8
# [3500]	training's rmse: 79.4252	training's l2: 6308.37	valid_1's rmse: 170.572	valid_1's l2: 29094.8
# [4000]	training's rmse: 73.6084	training's l2: 5418.19	valid_1's rmse: 169.623	valid_1's l2: 28772.1
# Early stopping, best iteration is:
# [4212]	training's rmse: 71.5247	training's l2: 5115.78	valid_1's rmse: 169.445	valid_1's l2: 28711.6
# ==============================
# MAE: 93.1321
# MSE: 28711.5934
# RMSE: 169.4450
# ==============================
#
#  ================== Fold 2 ==================
# Training until validation scores don't improve for 30 rounds
# [500]	training's rmse: 159.952	training's l2: 25584.8	valid_1's rmse: 238.577	valid_1's l2: 56918.8
# [1000]	training's rmse: 132.156	training's l2: 17465.3	valid_1's rmse: 224.895	valid_1's l2: 50577.5
# [1500]	training's rmse: 114.781	training's l2: 13174.6	valid_1's rmse: 219.768	valid_1's l2: 48298.1
# [2000]	training's rmse: 102.426	training's l2: 10491.2	valid_1's rmse: 216.727	valid_1's l2: 46970.8
# Early stopping, best iteration is:
# [2088]	training's rmse: 100.71	training's l2: 10142.4	valid_1's rmse: 216.436	valid_1's l2: 46844.7
# ==============================
# MAE: 100.7479
# MSE: 46844.7015
# RMSE: 216.4364
# ==============================
#
#  ================== Fold 3 ==================
# Training until validation scores don't improve for 30 rounds
# [500]	training's rmse: 160.471	training's l2: 25750.8	valid_1's rmse: 202.395	valid_1's l2: 40963.7
# [1000]	training's rmse: 131.682	training's l2: 17340.2	valid_1's rmse: 189.166	valid_1's l2: 35783.6
# [1500]	training's rmse: 114.521	training's l2: 13115.1	valid_1's rmse: 183.215	valid_1's l2: 33567.6
# [2000]	training's rmse: 102.574	training's l2: 10521.4	valid_1's rmse: 180.025	valid_1's l2: 32409
# [2500]	training's rmse: 93.1913	training's l2: 8684.62	valid_1's rmse: 177.756	valid_1's l2: 31597.2
# [3000]	training's rmse: 85.5123	training's l2: 7312.35	valid_1's rmse: 176.101	valid_1's l2: 31011.6
# [3500]	training's rmse: 79.3508	training's l2: 6296.55	valid_1's rmse: 175.034	valid_1's l2: 30637
# [4000]	training's rmse: 73.8961	training's l2: 5460.63	valid_1's rmse: 174.032	valid_1's l2: 30287.2
# Early stopping, best iteration is:
# [4050]	training's rmse: 73.3555	training's l2: 5381.03	valid_1's rmse: 173.925	valid_1's l2: 30250
# ==============================
# MAE: 95.4285
# MSE: 30249.9807
# RMSE: 173.9252
# ==============================
#
#  ================== Fold 4 ==================
# Training until validation scores don't improve for 30 rounds
# [500]	training's rmse: 161.204	training's l2: 25986.6	valid_1's rmse: 201.947	valid_1's l2: 40782.6
# [1000]	training's rmse: 132.666	training's l2: 17600.4	valid_1's rmse: 187.63	valid_1's l2: 35205
# [1500]	training's rmse: 115.441	training's l2: 13326.7	valid_1's rmse: 181.223	valid_1's l2: 32841.9
# [2000]	training's rmse: 102.875	training's l2: 10583.3	valid_1's rmse: 177.5	valid_1's l2: 31506.2
# [2500]	training's rmse: 93.9482	training's l2: 8826.27	valid_1's rmse: 175.517	valid_1's l2: 30806.3
# Early stopping, best iteration is:
# [2940]	training's rmse: 86.9234	training's l2: 7555.68	valid_1's rmse: 174.116	valid_1's l2: 30316.2
# ==============================
# MAE: 95.4082
# MSE: 30316.2466
# RMSE: 174.1156
# ==============================
#
#  ================== Fold 5 ==================
# Training until validation scores don't improve for 30 rounds
# [500]	training's rmse: 160.436	training's l2: 25739.6	valid_1's rmse: 198.04	valid_1's l2: 39219.7
# [1000]	training's rmse: 132.356	training's l2: 17518.2	valid_1's rmse: 185.61	valid_1's l2: 34451.1
# [1500]	training's rmse: 115.285	training's l2: 13290.6	valid_1's rmse: 179.838	valid_1's l2: 32341.9
# [2000]	training's rmse: 103.2	training's l2: 10650.2	valid_1's rmse: 176.417	valid_1's l2: 31122.9
# [2500]	training's rmse: 93.905	training's l2: 8818.15	valid_1's rmse: 174.368	valid_1's l2: 30404.1
# [3000]	training's rmse: 86.1898	training's l2: 7428.67	valid_1's rmse: 173.182	valid_1's l2: 29992.1
# Early stopping, best iteration is:
# [3264]	training's rmse: 82.5265	training's l2: 6810.63	valid_1's rmse: 172.576	valid_1's l2: 29782.6
# ==============================
# MAE: 95.9713
# MSE: 29782.6399
# RMSE: 172.5765
# ==============================

# %% [markdown]
# ## StratifiedKFold

# %%
def sKfold(train, N=None):
    skfold = StratifiedKFold(n_splits=N, shuffle=True, random_state=0)
    fold = 1
    models = {}

    for train_idx, valid_idx in skfold.split(features, features['num']):
        print('\n ================== sKFold {} =================='.format(fold))

        X_train, X_valid = features.iloc[train_idx, :], features.iloc[valid_idx, :]
        y_train, y_valid = labels.iloc[train_idx, :], labels.iloc[valid_idx, :]

        model = LGBMRegressor(n_estimators=10000, random_state=0)
        model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_valid, y_valid)], eval_metric= 'rmse', early_stopping_rounds=30, verbose=500)
        models[fold] = model
        
        pred = model.predict(X_valid)
        
        mae = mean_absolute_error(y_valid, pred)
        mse = mean_squared_error(y_valid, pred)
        rmse = np.sqrt(mean_squared_error(y_valid, pred))
        
        print('='*30)
        print('MAE: {0:.4f} \nMSE: {1:.4f} \nRMSE: {2:.4f}'.format(mae, mse, rmse))
        print('='*30)
        
        fold += 1
    
    return models

# %%
train, test, submission, features, labels = data_load(columns)
models = sKfold(train, 5)
# Out:
#  ================== sKFold 1 ==================
# Training until validation scores don't improve for 30 rounds
# [500]	training's rmse: 160.541	training's l2: 25773.5	valid_1's rmse: 207.524	valid_1's l2: 43066.2
# [1000]	training's rmse: 132.107	training's l2: 17452.2	valid_1's rmse: 194.592	valid_1's l2: 37866.2
# [1500]	training's rmse: 115.599	training's l2: 13363.1	valid_1's rmse: 188.509	valid_1's l2: 35535.5
# [2000]	training's rmse: 103.215	training's l2: 10653.3	valid_1's rmse: 185.234	valid_1's l2: 34311.5
# [2500]	training's rmse: 93.5116	training's l2: 8744.41	valid_1's rmse: 183.14	valid_1's l2: 33540.1
# [3000]	training's rmse: 85.9424	training's l2: 7386.1	valid_1's rmse: 181.831	valid_1's l2: 33062.3
# Early stopping, best iteration is:
# [2999]	training's rmse: 85.9553	training's l2: 7388.31	valid_1's rmse: 181.823	valid_1's l2: 33059.7
# ==============================
# MAE: 96.2148
# MSE: 33059.6609
# RMSE: 181.8232
# ==============================
#
#  ================== sKFold 2 ==================
# Training until validation scores don't improve for 30 rounds
# [500]	training's rmse: 160.554	training's l2: 25777.5	valid_1's rmse: 207.763	valid_1's l2: 43165.4
# [1000]	training's rmse: 133.262	training's l2: 17758.7	valid_1's rmse: 195.662	valid_1's l2: 38283.7
# [1500]	training's rmse: 116.229	training's l2: 13509.1	valid_1's rmse: 189.752	valid_1's l2: 36006
# [2000]	training's rmse: 103.958	training's l2: 10807.3	valid_1's rmse: 186.364	valid_1's l2: 34731.5
# [2500]	training's rmse: 94.6302	training's l2: 8954.87	valid_1's rmse: 183.968	valid_1's l2: 33844
# [3000]	training's rmse: 86.7188	training's l2: 7520.15	valid_1's rmse: 182.232	valid_1's l2: 33208.5
# [3500]	training's rmse: 80.2599	training's l2: 6441.65	valid_1's rmse: 180.835	valid_1's l2: 32701.3
# [4000]	training's rmse: 74.7708	training's l2: 5590.68	valid_1's rmse: 179.893	valid_1's l2: 32361.3
# [4500]	training's rmse: 69.9347	training's l2: 4890.86	valid_1's rmse: 179.259	valid_1's l2: 32133.8
# Early stopping, best iteration is:
# [4817]	training's rmse: 67.1718	training's l2: 4512.06	valid_1's rmse: 178.973	valid_1's l2: 32031.3
# ==============================
# MAE: 94.9309
# MSE: 32031.2685
# RMSE: 178.9728
# ==============================
#
#  ================== sKFold 3 ==================
# Training until validation scores don't improve for 30 rounds
# [500]	training's rmse: 159.802	training's l2: 25536.8	valid_1's rmse: 202.94	valid_1's l2: 41184.5
# [1000]	training's rmse: 131.541	training's l2: 17303.1	valid_1's rmse: 191.541	valid_1's l2: 36688.1
# [1500]	training's rmse: 114.557	training's l2: 13123.4	valid_1's rmse: 186.536	valid_1's l2: 34795.7
# [2000]	training's rmse: 102.531	training's l2: 10512.7	valid_1's rmse: 183.775	valid_1's l2: 33773.1
# [2500]	training's rmse: 93.5019	training's l2: 8742.6	valid_1's rmse: 181.965	valid_1's l2: 33111.2
# Early stopping, best iteration is:
# [2873]	training's rmse: 87.7374	training's l2: 7697.86	valid_1's rmse: 181.146	valid_1's l2: 32814
# ==============================
# MAE: 97.3034
# MSE: 32814.0174
# RMSE: 181.1464
# ==============================
#
#  ================== sKFold 4 ==================
# Training until validation scores don't improve for 30 rounds
# [500]	training's rmse: 160.862	training's l2: 25876.5	valid_1's rmse: 202.312	valid_1's l2: 40930.2
# [1000]	training's rmse: 132.388	training's l2: 17526.5	valid_1's rmse: 189.219	valid_1's l2: 35804
# [1500]	training's rmse: 114.907	training's l2: 13203.7	valid_1's rmse: 183.23	valid_1's l2: 33573.2
# [2000]	training's rmse: 102.403	training's l2: 10486.4	valid_1's rmse: 179.861	valid_1's l2: 32350.1
# [2500]	training's rmse: 93.0489	training's l2: 8658.1	valid_1's rmse: 177.709	valid_1's l2: 31580.3
# [3000]	training's rmse: 85.4501	training's l2: 7301.71	valid_1's rmse: 176.19	valid_1's l2: 31043
# Early stopping, best iteration is:
# [3384]	training's rmse: 80.3225	training's l2: 6451.7	valid_1's rmse: 175.365	valid_1's l2: 30752.9
# ==============================
# MAE: 95.5850
# MSE: 30752.8680
# RMSE: 175.3650
# ==============================
#
#  ================== sKFold 5 ==================
# Training until validation scores don't improve for 30 rounds
# [500]	training's rmse: 160.975	training's l2: 25912.8	valid_1's rmse: 217.32	valid_1's l2: 47228
# [1000]	training's rmse: 131.621	training's l2: 17324	valid_1's rmse: 204.268	valid_1's l2: 41725.3
# [1500]	training's rmse: 114.564	training's l2: 13124.9	valid_1's rmse: 198.412	valid_1's l2: 39367.4
# [2000]	training's rmse: 102.703	training's l2: 10547.9	valid_1's rmse: 195.121	valid_1's l2: 38072.4
# Early stopping, best iteration is:
# [2044]	training's rmse: 101.85	training's l2: 10373.5	valid_1's rmse: 194.957	valid_1's l2: 38008.4
# ==============================
# MAE: 98.8795
# MSE: 38008.3776
# RMSE: 194.9574
# ==============================

# %% [markdown]
# ## RandomForest

# %%
def KfoldForest(train, N=None):
    kfold = KFold(n_splits=N, shuffle=True, random_state=0)
    fold = 1
    models = {}

    for train_idx, valid_idx in kfold.split(train):
        print('\n ================== Fold {} =================='.format(fold))

        X_train, X_valid = features.iloc[train_idx, :], features.iloc[valid_idx, :]
        y_train, y_valid = labels.iloc[train_idx, :], labels.iloc[valid_idx, :]
        
        
        model = RandomForestRegressor(random_state=0)
        model.fit(X_train, y_train)
        pred = model.predict(X_valid)
        
        mae = mean_absolute_error(y_valid, pred)
        mse = mean_squared_error(y_valid, pred)
        rmse = np.sqrt(mean_squared_error(y_valid, pred))
        
        print('MAE: {0:.4f} \nMSE: {1:.4f} \nRMSE: {2:.4f}'.format(mae, mse, rmse))
        
        models[fold] = model

        fold += 1
    
    return models

# %%
train, test, submission, features, labels = data_load(columns)
models = KfoldForest(train, 5)
# Out:
#  ================== Fold 1 ==================
# MAE: 112.4019
# MSE: 49774.5470
# RMSE: 223.1021
#
#  ================== Fold 2 ==================
# MAE: 116.6566
# MSE: 68836.8379
# RMSE: 262.3678
#
#  ================== Fold 3 ==================
# MAE: 116.0191
# MSE: 55604.7868
# RMSE: 235.8067
#
#  ================== Fold 4 ==================
# MAE: 114.9101
# MSE: 57782.0016
# RMSE: 240.3789
#
#  ================== Fold 5 ==================
# MAE: 114.5944
# MSE: 53244.0506
# RMSE: 230.7467

# %%
submission = pd.read_csv('energy/sample_submission.csv', encoding='cp949')

for i in range(1, 6):
    submission['answer'] += models[i].predict(test)/5

submission.to_csv('lgbm_day4_3.csv', index=False)
